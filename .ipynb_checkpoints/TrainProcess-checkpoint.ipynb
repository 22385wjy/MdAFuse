# %%
import time
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import glob
import imageio
import natsort
from pytorch_msssim import ssim
import os
import os.path
import multiprocessing
import scipy.io as scio
from PIL import Image
import cv2
import matplotlib
import scipy.misc

# %%
device = 'cuda:2' if torch.cuda.is_available() else 'cpu'
image_length = 256
image_width = 256
mr_channels = 1
gray_channels = 1
pet_channels = 4
rgb_channels = 2
batch_size = 2
EPOCH = 61
learning_rate = 0.0001  #0.002  default is 0.001

# %%
def load_mrt1_data():
    # load the train mri data     #'C:/Users/HP/Desktop/DeepTreeFuse/Data/MRI')   #'/home/wenjinyu/Desktop/DeepTreeFuse/Data/MRI') 
    dataset = os.path.join(os.getcwd(), '../../data_add_t2pet/MR-T2') 
    data = glob.glob(os.path.join(dataset, "*.*"))
    data = natsort.natsorted(data, reverse=False)
    print(len(data))
    train_mrt1 = np.zeros((len(data), image_width, image_length))
    for i in range(len(data)):
        train_mrt1[i, :, :] = (imageio.imread(data[i]))
        train_mrt1[i, :, :] = (train_mrt1[i, :, :] - np.min(train_mrt1[i, :, :])) / (
                    np.max(train_mrt1[i, :, :]) - np.min(train_mrt1[i, :, :]))
        train_mrt1[i, :, :] = np.float32(train_mrt1[i, :, :])

    # expand dimension to add the channel
    train_mrt1 = np.expand_dims(train_mrt1, axis=1)

    # convert the MRI training data to pytorch tensor
    train_mrt1_tensor = torch.from_numpy(train_mrt1).float()
    print('train_mrt1_tensor: ',train_mrt1_tensor.shape)

    return train_mrt1_tensor

# %%
def load_pet_data():
    # load the train pet data
    #filenames = os.listdir('C:/Users/horan/Desktop/FuseVis/Training/PET')
    dataset = os.path.join(os.getcwd(), '../../data_add_t2pet/FDG')
    data = glob.glob(os.path.join(dataset, "*.*"))
    data = natsort.natsorted(data, reverse=False)
    train_other = np.zeros((len(data), image_width, image_length, pet_channels), dtype=float)
    train_pet = np.zeros((len(data), image_width, image_length), dtype=float)
    for i in range(len(data)):
        train_other[i, :, :, :] = (imageio.imread(data[i]))
        train_pet[i, :, :] = 0.2989 * train_other[i, :, :, 0] + 0.5870 * train_other[i, :, :, 1] + 0.1140 * train_other[
                                                                                                            i, :, :, 2]
        train_pet[i, :, :] = (train_pet[i, :, :] - np.min(train_pet[i, :, :])) / (
                    np.max(train_pet[i, :, :]) - np.min(train_pet[i, :, :]))

    # expand the dimension to add the channel
    train_pet = np.expand_dims(train_pet, axis=1)

    # convert the PET training data to pytorch tensor
    train_pet_tensor = torch.from_numpy(train_pet).float()
    print('train_pet_tensor: ',train_pet_tensor.shape)

    return train_pet_tensor

# %%
class _LFConv1(nn.Module):
    def __init__(self):
        super(_LFConv1, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm2d(32),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class _LFConv2(nn.Module):
    def __init__(self):
        super(_LFConv2, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=2, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm2d(2),
            nn.ReLU(True),
            nn.Conv2d(2, 4, 7, 1, 3),
            nn.BatchNorm2d(4),
            nn.ReLU(True),
            nn.Conv2d(4, 8, 7, 1, 3),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 7, 1, 3),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 7, 1, 3),
            nn.BatchNorm2d(32),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class _HFConv1(nn.Module):
    def __init__(self):
        super(_HFConv1, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class _HFConv2(nn.Module):
    def __init__(self):
        super(_HFConv2, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True)
        )
        self.conv6 = nn.Sequential(
            nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True)
        )
        self.pool = nn.MaxPool2d(2, 2)
        #self.up = nn.Upsample(scale_factor=2)

    def upsample(self, x, size):
        return nn.functional.interpolate(x, size, mode='bilinear', align_corners=True)

    def forward(self, x):
        x1=self.conv1(x)
        x2=self.pool(x1)
        x3=self.conv2(x2)
        x4=self.conv3(x3)
        x5=self.upsample(x4,(256,256))
        x1_2=self.conv2(x1)
        x5_2=self.conv6(x5)
        cat=torch.cat((x1_2,x5_2),1)
        x6=self.conv4(cat)

        return x6

def denorm(mean=[0, 0, 0], std=[1, 1, 1], tensor=None):
    for t, m, s in zip(tensor, mean, std):
        t.mul_(s).add_(m)
    return tensor

class forOriginal(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=0, **kwargs):
        super(forOriginal, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class DsConv(nn.Module):
    def __init__(self, dw_channels, out_channels, stride=1, **kwargs):
        super(DsConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(dw_channels, dw_channels, 3, stride, 1, groups=dw_channels, bias=False),
            nn.BatchNorm2d(dw_channels),
            nn.ReLU(True),
            nn.Conv2d(dw_channels, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class downsample(nn.Module):
    def __init__(self, dw_channels1=16, dw_channels2=32, out_channels=64, **kwargs):
        super(downsample, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, dw_channels1, 3, 2),
            nn.BatchNorm2d(dw_channels1),
            nn.ReLU(True)
        )
        self.dsconv1 = DsConv(dw_channels1, dw_channels2, 2)

    def forward(self, x):
        x1 = self.conv(x)
        x2 = self.dsconv1(x1)
        
        return x1,x2

class SegConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=0, **kwargs):
        super(SegConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class SegConv2(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, **kwargs):
        super(SegConv2, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, 1, groups=in_channels, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True)
        )

    def forward(self, x):
        return self.conv(x)

class PoolandUp(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(PoolandUp, self).__init__()
        inter_channels = int(in_channels / 2)
        self.conv1 = SegConv(in_channels, inter_channels, 1, **kwargs)
        self.out = SegConv(in_channels, out_channels, 1)

    def pool(self, x, size):
        avgpool = nn.AdaptiveAvgPool2d(size)
        return avgpool(x)

    def upsample(self, x, size):
        return nn.functional.interpolate(x, size, mode='bilinear', align_corners=True)

    def forward(self, x):
        size = x.size()[2:]
        p1 = self.pool(x, int(size[0]/2))
        cp1 = self.conv1(p1)
        ucp1 = self.upsample(cp1, size)

        x=self.upsample(self.conv1(x), size)

        x = torch.cat([x, ucp1], dim=1)
        x = self.out(x)
        
        return x

class SeFeature(nn.Module):
    def __init__(self, in_channels, out_channels, t=2, stride=2, **kwargs):
        super(SeFeature, self).__init__()
        self.block = nn.Sequential(
            SegConv(in_channels, in_channels * t, 1),
            SegConv2(in_channels * t, in_channels * t ),
            nn.Conv2d(in_channels * t, out_channels, 1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        self.pool_up=PoolandUp(32,32)

    def forward(self, x):
        out1 = self.block(x)
        out=self.pool_up(out1)
        return out

class segment(nn.Module):
    def __init__(self, in_channels, num_classes, stride=1, **kwargs):
        super(segment, self).__init__()
        self.conv1 = DsConv(in_channels, in_channels, stride)
        self.conv = nn.Sequential(
            nn.Dropout(0.1),
            nn.Conv2d(in_channels, num_classes, 1)
        )

    def forward(self, x):
        size = x.size()[2:]
        x1 = self.conv1(x)
        x2 = self.conv(x1)

        return x2

# %%
class AffineTransform(nn.Module):
    def __init__(self,num_features):
        super().__init__()
        self.alpha=nn.Parameter(torch.ones(1,1,num_features))
        self.beta=nn.Parameter(torch.zeros(1,1,num_features))
        
    def forward(self,x):
        return self.alpha*x+self.beta

# %%
def net():
    # define the network
    class DeepTreeFuse(nn.Module):
        def __init__(self,num_classes=3):
            super(DeepTreeFuse, self).__init__()

            #####one lf layer 1#####
            self.one_lf1 =_LFConv1()
            self.one_lf2 = _LFConv2()
            #####one hf layers#####
            self.one_hf1 =_HFConv1()
            self.one_hf2 = _HFConv2()

            #####two lf layer 1#####
            self.two_lf1 = _LFConv1()
            self.two_lf2 = _LFConv2()
            #####two hf layers#####
            self.two_hf1 = _HFConv1()
            self.two_hf2 = _HFConv2()

            self.l_o=forOriginal(1,16,7,1,3)
            self.h_o = forOriginal(1, 16, 3, 1, 3)

            # lf reconstruction
            self.lf_recons = nn.Sequential(
                nn.Conv2d(in_channels=64, out_channels=32, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(32),
                nn.ReLU(True),
                nn.Conv2d(in_channels=32, out_channels=16, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(16),
                nn.ReLU(True)
            )  # output shape (,16,256,256)

            # hf reconstruction
            self.hf_recons = nn.Sequential(
                nn.Conv2d(in_channels=256, out_channels=128, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(128),
                nn.ReLU(True),
                nn.Conv2d(in_channels=128, out_channels=64, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(64),
                nn.ReLU(True),
                nn.Conv2d(in_channels=64, out_channels=32, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(32),
                nn.ReLU(True),
                nn.Conv2d(in_channels=32, out_channels=16, kernel_size=5, stride=1,
                          padding=2),
                nn.BatchNorm2d(16),
                nn.ReLU(True),
            )  # output shape (,16,256,256)

            # final reconstruction
            self.recon = nn.Sequential(  # input shape (,16, 256, 256)
                nn.Conv2d(in_channels=16, out_channels=3, kernel_size=5, stride=1,
                          padding=2))  # output shape (,3,256,256)
            self.hf2con = nn.Sequential(  # input shape (,16, 256, 256)
                nn.Conv2d(in_channels=16, out_channels=16, kernel_size=5, stride=1,
                          padding=2))
            self.reconse = nn.Sequential(
                nn.Conv2d(in_channels=3, out_channels=3, kernel_size=5, stride=1,
                          padding=2))
            self.re = nn.Sequential(
                nn.Conv2d(in_channels=3, out_channels=1, kernel_size=3, stride=1,
                          padding=1))

            # semantic feature extract
            self.downsample = downsample()
            self.globalfeature = SeFeature(32, 32)
            self.otherconv = SegConv2(32, 32)
            self.merge = nn.Sequential(
                nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1,
                          padding=1),
                nn.BatchNorm2d(32),
                nn.ReLU(inplace=False)
            )

            self.segclass = segment(32, num_classes=3)
            self.dropandplt = nn.Sequential(
                nn.Conv2d(32, 16, 3, padding=1, bias=False),
                nn.BatchNorm2d(16),
                nn.ReLU(True),
                nn.Dropout(0.1),
                nn.Conv2d(16, num_classes, 1)
            )
            self.x0 = nn.Sequential(nn.Conv2d(1, 32, 3, padding=1, bias=False),
                                    nn.BatchNorm2d(32),
                                    nn.ReLU(True))
            self.x1 = nn.Sequential(nn.Conv2d(16, 32, 3, padding=1, bias=False),
                                    nn.BatchNorm2d(32),
                                    nn.ReLU(True))
            self.x2 = nn.Sequential(nn.Conv2d(32, 32, 3, padding=1, bias=False),
                                    nn.BatchNorm2d(32),
                                    nn.ReLU(True))
            self.xxx = nn.Sequential(nn.Conv2d(96, 64, 3, padding=1, bias=False),
                                     nn.BatchNorm2d(64),
                                     nn.ReLU(True),
                                     nn.Conv2d(64, 32, 3, padding=1, bias=False),
                                     nn.BatchNorm2d(32),
                                     nn.ReLU(True)
                                     )
            self.aff=AffineTransform(256)

        def upsample(self, x, size):
            return nn.functional.interpolate(x, size, mode='bilinear', align_corners=True)

        def tensor_max(self, tensors):
            max_tensor = None
            for i, tensor in enumerate(tensors):
                if i == 0:
                    max_tensor = tensor
                else:
                    max_tensor = torch.max(max_tensor, tensor)
            return max_tensor

        def obtain_to_LHF(self, tensor):
            # lf
            x=tensor
            lf1 = self.one_lf1(x)
            lf2 = self.one_lf2(x)
            x1 = torch.cat((lf1, lf2), 1)
            lf_x = self.lf_recons(x1)
            # hf
            hf1 = self.one_hf1(x)
            hf2 = self.one_hf2(x)
            x2 = torch.cat((hf1, hf2), 1)
            hf_x = self.hf_recons(x2)
            x_change_c_ol = self.l_o(x)
            x_change_c_oh = self.h_o(x)
            outx =lf_x+hf_x

            return lf_x,hf_x,outx,x_change_c_ol,x_change_c_oh

        def semantic_one(self,tensor):
            x=tensor
            sx, se = self.downsample(x)
            s1 = self.globalfeature(se)
            s2 = self.otherconv(se)
            s = s1 + s2
            out_s = self.merge(s)
            out_up = self.upsample(out_s, (128, 128))
            sclass = self.segclass(out_up)
            size = x.size()[2:]
            sclass = self.upsample(sclass, size)
            result_S = sclass
            x0 = self.x0(x)
            sx = self.x1(sx)
            se2 = self.x2(se)
            sx = self.upsample(sx, size)
            se2 = self.upsample(se2, size)
            x0 = self.dropandplt(x0)  # self.segclass(x0)
            sx = self.segclass(sx)
            se2 = self.segclass(se2)
            x3_out = x0 + sx + se2
            total_seg1 = result_S + x3_out
            
            return total_seg1
    
        def doFuse(self,t1,t2,t3,t4,xl,xh,yl,yh,cx_l,cx_h,cy_l,cy_h):
            lhf_x=t1
            lhf_y=t2
            se_x=t3
            se_y=t4
            xh=self.aff(xh)
            xl=self.aff(xl)
            yh=self.aff(yh)
            yl=self.aff(yl)
            
            HF = xh + yh
            LF = xl + yl
            fu_lf_hf = self.tensor_max([HF, LF])

            lf_hf = self.recon(fu_lf_hf)
            lf_hf = self.aff(lf_hf)

            out_se = (se_x + se_y) / 2
            out_se = self.aff(out_se)
            
            fuseout = (lf_hf + out_se) / 2
            fuseout = torch.tanh(fuseout)

            return fuseout

        def forward(self, x, y): # lf,hf,pyramid and reconstruction of mul-type
            #print(torch.equal(x, y))
            ## extract deep features
            # __________________ one type __________________

            lf_x,hf_x,lhf_x,cx_l,cx_h=self.obtain_to_LHF(x)
            se_x=self.semantic_one(x)  # semantic
            #print('one type result out **********')

            # __________________ two type __________________
            lf_y, hf_y, lhf_y,cy_l,cy_h = self.obtain_to_LHF(y)
            se_y = self.semantic_one(y)
            #print('the other type result out **********')
            
            ## to do fusing
            fuseout=self.doFuse(lhf_x,lhf_y,se_x,se_y,lf_x,hf_x,lf_y, hf_y,cx_l,cx_h,cy_l,cy_h)
            fuseout=self.re(fuseout)
            
            return fuseout

    dtn = DeepTreeFuse().to(device)
    dtn = dtn.float()
    #print(dtn)

    return dtn

# %%
def train_for_model(dtn,train_mri_tensor,train_pet_tensor):
    # define the optimizers and loss functions
    optimizer = torch.optim.Adam(dtn.parameters(), lr=learning_rate)  # optimize all dtn parameters
    l2_loss = nn.MSELoss()  # MSEloss

    # perform the training
    counter = 0
    start_time = time.time()
    lamda = 0.7
    loss_history=[]
    output=torch.empty(2,1,256,256)
    nn.init.constant_(output, 0.3)
    for epoch in range(EPOCH):
        # run batch images
        batch_idxs = 555 // batch_size
        for idx in range(0, batch_idxs):
            b_x = train_mri_tensor[idx * batch_size: (idx + 1) * batch_size, :, :, :].to(device)
            b_y = train_pet_tensor[idx * batch_size: (idx + 1) * batch_size, :, :, :].to(device)
            counter += 1
            output = dtn(b_x, b_y)  # output

            ssim_loss_mri = 1 - ssim(output, b_x, data_range=1)
            ssim_loss_pet = 1 - ssim(output, b_y, data_range=1)
            ssim_total = ssim_loss_mri + ssim_loss_pet
            l2_total = l2_loss(output, b_x) + l2_loss(output, b_y)
            loss_total = (1 - lamda) * ssim_total + lamda * l2_total

            optimizer.zero_grad()
            #loss_total.backward(retain_graph=True)
            loss_total.backward()
            optimizer.step()
            loss_history.append(loss_total.item())

            if counter % 15 == 0:
                print(
                    "Epoch: [%2d],step: [%2d], mri_ssim: [%.8f], pet_ssim: [%.8f],  total_ssim: [%.8f], total_l2: [%.8f], total_loss: [%.8f]"
                    % (epoch, counter, ssim_loss_mri, ssim_loss_pet, ssim_total, l2_total, loss_total))

            if (epoch == EPOCH - 1):
                # Save a checkpoint
                torch.save(dtn.state_dict(), './MineCheckpoint.pth', _use_new_zipfile_serialization=False)
                print('*************obtained net model')

                return loss_history

# %%
train_mrt1_tensor = load_mrt1_data().to(device)
print(train_mrt1_tensor.shape)
# Out:
# 555
# train_mrt1_tensor:  torch.Size([555, 1, 256, 256])
# torch.Size([555, 1, 256, 256])

# %%
train_pet_tensor = load_pet_data().to(device)
print(train_pet_tensor.shape)
# Out:
# train_pet_tensor:  torch.Size([555, 1, 256, 256])
# torch.Size([555, 1, 256, 256])

# %%
new_cnn = net()

# %%
print(device)
# Out:
# cuda:2

# %%
loss_history=train_for_model(new_cnn, train_mrt1_tensor, train_pet_tensor)
plt.plot(loss_history,label='loss for every epoch')
plt.show()
print('finish fusing')
# Out:
# Epoch: [ 0],step: [ 5], mri_ssim: [0.82098305], pet_ssim: [0.82503808],  total_ssim: [1.64602113], total_l2: [0.03396789], total_loss: [0.51758391]
# Epoch: [ 0],step: [10], mri_ssim: [0.72193038], pet_ssim: [0.79544044],  total_ssim: [1.51737082], total_l2: [0.04396223], total_loss: [0.48598480]
# Epoch: [ 0],step: [15], mri_ssim: [0.70651579], pet_ssim: [0.76437908],  total_ssim: [1.47089481], total_l2: [0.03440421], total_loss: [0.46535143]
# Epoch: [ 0],step: [20], mri_ssim: [0.69821817], pet_ssim: [0.73446929],  total_ssim: [1.43268752], total_l2: [0.04102504], total_loss: [0.45852378]
# Epoch: [ 0],step: [25], mri_ssim: [0.67660296], pet_ssim: [0.70902461],  total_ssim: [1.38562751], total_l2: [0.03032708], total_loss: [0.43691725]
# Epoch: [ 0],step: [30], mri_ssim: [0.70236242], pet_ssim: [0.77091324],  total_ssim: [1.47327566], total_l2: [0.04982836], total_loss: [0.47686255]
# Epoch: [ 0],step: [35], mri_ssim: [0.66169095], pet_ssim: [0.72544014],  total_ssim: [1.38713109], total_l2: [0.04157391], total_loss: [0.44524106]
# Epoch: [ 0],step: [40], mri_ssim: [0.53853947], pet_ssim: [0.58694196],  total_ssim: [1.12548137], total_l2: [0.04710438], total_loss: [0.37061751]
# Epoch: [ 0],step: [45], mri_ssim: [0.63675463], pet_ssim: [0.62489295],  total_ssim: [1.26164758], total_l2: [0.04854039], total_loss: [0.41247258]
# Epoch: [ 0],step: [50], mri_ssim: [0.86047316], pet_ssim: [0.84974450],  total_ssim: [1.71021771], total_l2: [0.04518983], total_loss: [0.54469824]
# Epoch: [ 0],step: [55], mri_ssim: [0.85037649], pet_ssim: [0.85584140],  total_ssim: [1.70621789], total_l2: [0.03446910], total_loss: [0.53599375]
# Epoch: [ 0],step: [60], mri_ssim: [0.84451866], pet_ssim: [0.85629576],  total_ssim: [1.70081449], total_l2: [0.02784559], total_loss: [0.52973628]
# Epoch: [ 0],step: [65], mri_ssim: [0.80470806], pet_ssim: [0.84197408],  total_ssim: [1.64668214], total_l2: [0.02680831], total_loss: [0.51277047]
# Epoch: [ 0],step: [70], mri_ssim: [0.82552063], pet_ssim: [0.85202891],  total_ssim: [1.67754960], total_l2: [0.02572944], total_loss: [0.52127552]
# Epoch: [ 0],step: [75], mri_ssim: [0.75774604], pet_ssim: [0.84660995],  total_ssim: [1.60435605], total_l2: [0.03145417], total_loss: [0.50332475]
# Epoch: [ 0],step: [80], mri_ssim: [0.79461330], pet_ssim: [0.86142981],  total_ssim: [1.65604305], total_l2: [0.04269000], total_loss: [0.52669597]
# Epoch: [ 0],step: [85], mri_ssim: [0.80998504], pet_ssim: [0.86045659],  total_ssim: [1.67044163], total_l2: [0.04873167], total_loss: [0.53524464]
# Epoch: [ 0],step: [90], mri_ssim: [0.78687418], pet_ssim: [0.86117637],  total_ssim: [1.64805055], total_l2: [0.04533479], total_loss: [0.52614957]
# Epoch: [ 0],step: [95], mri_ssim: [0.72657377], pet_ssim: [0.74960262],  total_ssim: [1.47617638], total_l2: [0.03231597], total_loss: [0.46547413]
# Epoch: [ 0],step: [100], mri_ssim: [0.69067550], pet_ssim: [0.76845670],  total_ssim: [1.45913219], total_l2: [0.04208439], total_loss: [0.46719873]
# Epoch: [ 0],step: [105], mri_ssim: [0.53301531], pet_ssim: [0.58814341],  total_ssim: [1.12115872], total_l2: [0.02486049], total_loss: [0.35374999]
# Epoch: [ 0],step: [110], mri_ssim: [0.61143732], pet_ssim: [0.70841753],  total_ssim: [1.31985486], total_l2: [0.02405055], total_loss: [0.41279188]
# Epoch: [ 0],step: [115], mri_ssim: [0.60418910], pet_ssim: [0.74512255],  total_ssim: [1.34931159], total_l2: [0.02640161], total_loss: [0.42327464]
# Epoch: [ 0],step: [120], mri_ssim: [0.49124116], pet_ssim: [0.50495040],  total_ssim: [0.99619156], total_l2: [0.02577562], total_loss: [0.31690040]
# Epoch: [ 0],step: [125], mri_ssim: [0.54949760], pet_ssim: [0.56808668],  total_ssim: [1.11758423], total_l2: [0.03334478], total_loss: [0.35861665]
# Epoch: [ 0],step: [130], mri_ssim: [0.84099746], pet_ssim: [0.84408343],  total_ssim: [1.68508089], total_l2: [0.02155427], total_loss: [0.52061224]
# Epoch: [ 0],step: [135], mri_ssim: [0.75128067], pet_ssim: [0.78435433],  total_ssim: [1.53563499], total_l2: [0.02190025], total_loss: [0.47602069]
# Epoch: [ 0],step: [140], mri_ssim: [0.60999966], pet_ssim: [0.76851225],  total_ssim: [1.37851191], total_l2: [0.04686378], total_loss: [0.44635823]
# Epoch: [ 0],step: [145], mri_ssim: [0.46730536], pet_ssim: [0.57677531],  total_ssim: [1.04408073], total_l2: [0.04560399], total_loss: [0.34514701]
# Epoch: [ 0],step: [150], mri_ssim: [0.52533531], pet_ssim: [0.61218518],  total_ssim: [1.13752055], total_l2: [0.04726809], total_loss: [0.37434384]
# Epoch: [ 0],step: [155], mri_ssim: [0.48005027], pet_ssim: [0.57527918],  total_ssim: [1.05532944], total_l2: [0.04855525], total_loss: [0.35058752]
# Epoch: [ 0],step: [160], mri_ssim: [0.45175314], pet_ssim: [0.55353916],  total_ssim: [1.00529230], total_l2: [0.04302926], total_loss: [0.33170819]
# Epoch: [ 0],step: [165], mri_ssim: [0.46340376], pet_ssim: [0.62282532],  total_ssim: [1.08622909], total_l2: [0.04090223], total_loss: [0.35450029]
# Epoch: [ 0],step: [170], mri_ssim: [0.39723897], pet_ssim: [0.60792243],  total_ssim: [1.00516140], total_l2: [0.04297861], total_loss: [0.33163345]
# Epoch: [ 0],step: [175], mri_ssim: [0.37150455], pet_ssim: [0.60814410],  total_ssim: [0.97964865], total_l2: [0.04731187], total_loss: [0.32701293]
# Epoch: [ 0],step: [180], mri_ssim: [0.34359741], pet_ssim: [0.61638129],  total_ssim: [0.95997870], total_l2: [0.04868633], total_loss: [0.32207406]
# Epoch: [ 0],step: [185], mri_ssim: [0.32729793], pet_ssim: [0.61485410],  total_ssim: [0.94215202], total_l2: [0.04867908], total_loss: [0.31672096]
# Epoch: [ 0],step: [190], mri_ssim: [0.68254977], pet_ssim: [0.82461333],  total_ssim: [1.50716305], total_l2: [0.04822360], total_loss: [0.48590547]
# Epoch: [ 0],step: [195], mri_ssim: [0.66077673], pet_ssim: [0.78128529],  total_ssim: [1.44206202], total_l2: [0.05368950], total_loss: [0.47020125]
# Epoch: [ 0],step: [200], mri_ssim: [0.62047625], pet_ssim: [0.78097141],  total_ssim: [1.40144765], total_l2: [0.05039499], total_loss: [0.45571083]
# Epoch: [ 0],step: [205], mri_ssim: [0.59517580], pet_ssim: [0.77581757],  total_ssim: [1.37099338], total_l2: [0.04777790], total_loss: [0.44474256]
# Epoch: [ 0],step: [210], mri_ssim: [0.48661643], pet_ssim: [0.68738902],  total_ssim: [1.17400551], total_l2: [0.05681852], total_loss: [0.39197463]
# Epoch: [ 0],step: [215], mri_ssim: [0.42916787], pet_ssim: [0.62606877],  total_ssim: [1.05523658], total_l2: [0.05113634], total_loss: [0.35236645]
# Epoch: [ 0],step: [220], mri_ssim: [0.40155745], pet_ssim: [0.60965061],  total_ssim: [1.01120806], total_l2: [0.05335510], total_loss: [0.34071100]
# Epoch: [ 0],step: [225], mri_ssim: [0.33675998], pet_ssim: [0.59523398],  total_ssim: [0.93199396], total_l2: [0.05415761], total_loss: [0.31750852]
# Epoch: [ 0],step: [230], mri_ssim: [0.40122217], pet_ssim: [0.80125439],  total_ssim: [1.20247650], total_l2: [0.06071514], total_loss: [0.40324354]
# Epoch: [ 0],step: [235], mri_ssim: [0.43496960], pet_ssim: [0.70259786],  total_ssim: [1.13756752], total_l2: [0.05333697], total_loss: [0.37860614]
# Epoch: [ 0],step: [240], mri_ssim: [0.40083629], pet_ssim: [0.62646443],  total_ssim: [1.02730072], total_l2: [0.05130878], total_loss: [0.34410638]
# Epoch: [ 0],step: [245], mri_ssim: [0.39872539], pet_ssim: [0.58017129],  total_ssim: [0.97889668], total_l2: [0.05662740], total_loss: [0.33330819]
# Epoch: [ 0],step: [250], mri_ssim: [0.39140880], pet_ssim: [0.56463856],  total_ssim: [0.95604736], total_l2: [0.05048465], total_loss: [0.32215348]
# Epoch: [ 0],step: [255], mri_ssim: [0.39773750], pet_ssim: [0.53696257],  total_ssim: [0.93470007], total_l2: [0.05505028], total_loss: [0.31894523]
# Epoch: [ 0],step: [260], mri_ssim: [0.36314493], pet_ssim: [0.50040781],  total_ssim: [0.86355275], total_l2: [0.04875112], total_loss: [0.29319161]
# Epoch: [ 0],step: [265], mri_ssim: [0.38781339], pet_ssim: [0.51475108],  total_ssim: [0.90256447], total_l2: [0.04334204], total_loss: [0.30110878]
# Epoch: [ 0],step: [270], mri_ssim: [0.34419453], pet_ssim: [0.46522272],  total_ssim: [0.80941725], total_l2: [0.04349954], total_loss: [0.27327487]
# Epoch: [ 0],step: [275], mri_ssim: [0.31146729], pet_ssim: [0.49404550],  total_ssim: [0.80551279], total_l2: [0.03952266], total_loss: [0.26931971]
# Epoch: [ 1],step: [280], mri_ssim: [0.38615751], pet_ssim: [0.45944369],  total_ssim: [0.84560120], total_l2: [0.01971294], total_loss: [0.26747945]
# Epoch: [ 1],step: [285], mri_ssim: [0.47303331], pet_ssim: [0.61618388],  total_ssim: [1.08921719], total_l2: [0.02495434], total_loss: [0.34423321]
# Epoch: [ 1],step: [290], mri_ssim: [0.40693855], pet_ssim: [0.49309623],  total_ssim: [0.90003479], total_l2: [0.02100425], total_loss: [0.28471342]
# Epoch: [ 1],step: [295], mri_ssim: [0.52872229], pet_ssim: [0.60360670],  total_ssim: [1.13232899], total_l2: [0.02387430], total_loss: [0.35641071]
# Epoch: [ 1],step: [300], mri_ssim: [0.53314364], pet_ssim: [0.56060863],  total_ssim: [1.09375226], total_l2: [0.02247183], total_loss: [0.34385598]
# Epoch: [ 1],step: [305], mri_ssim: [0.43102610], pet_ssim: [0.52855259],  total_ssim: [0.95957869], total_l2: [0.02805698], total_loss: [0.30751351]
# Epoch: [ 1],step: [310], mri_ssim: [0.45183253], pet_ssim: [0.54423463],  total_ssim: [0.99606717], total_l2: [0.03792520], total_loss: [0.32536781]
# Epoch: [ 1],step: [315], mri_ssim: [0.34304869], pet_ssim: [0.44829106],  total_ssim: [0.79133976], total_l2: [0.04050776], total_loss: [0.26575735]
# Epoch: [ 1],step: [320], mri_ssim: [0.38560677], pet_ssim: [0.36822975],  total_ssim: [0.75383651], total_l2: [0.03843897], total_loss: [0.25305822]
# Epoch: [ 1],step: [325], mri_ssim: [0.39408410], pet_ssim: [0.37757707],  total_ssim: [0.77166116], total_l2: [0.03380901], total_loss: [0.25516468]
# Epoch: [ 1],step: [330], mri_ssim: [0.34768689], pet_ssim: [0.33820081],  total_ssim: [0.68588769], total_l2: [0.02482251], total_loss: [0.22314207]
# Epoch: [ 1],step: [335], mri_ssim: [0.31408221], pet_ssim: [0.31302226],  total_ssim: [0.62710446], total_l2: [0.02188954], total_loss: [0.20345402]
# Epoch: [ 1],step: [340], mri_ssim: [0.30241537], pet_ssim: [0.31610751],  total_ssim: [0.61852288], total_l2: [0.02197808], total_loss: [0.20094153]
# Epoch: [ 1],step: [345], mri_ssim: [0.29037571], pet_ssim: [0.31334066],  total_ssim: [0.60371637], total_l2: [0.02111641], total_loss: [0.19589640]
# Epoch: [ 1],step: [350], mri_ssim: [0.54648304], pet_ssim: [0.64602274],  total_ssim: [1.19250584], total_l2: [0.02652846], total_loss: [0.37632167]
# Epoch: [ 1],step: [355], mri_ssim: [0.50432956], pet_ssim: [0.60521209],  total_ssim: [1.10954165], total_l2: [0.02857867], total_loss: [0.35286757]
# Epoch: [ 1],step: [360], mri_ssim: [0.37916297], pet_ssim: [0.46145594],  total_ssim: [0.84061891], total_l2: [0.01945117], total_loss: [0.26580149]
# Epoch: [ 1],step: [365], mri_ssim: [0.31314945], pet_ssim: [0.38637686],  total_ssim: [0.69952631], total_l2: [0.02336624], total_loss: [0.22621426]
# Epoch: [ 1],step: [370], mri_ssim: [0.35030735], pet_ssim: [0.42787802],  total_ssim: [0.77818537], total_l2: [0.02304033], total_loss: [0.24958384]
# Epoch: [ 1],step: [375], mri_ssim: [0.36596906], pet_ssim: [0.45666564],  total_ssim: [0.82263470], total_l2: [0.02487931], total_loss: [0.26420593]
# Epoch: [ 1],step: [380], mri_ssim: [0.44532931], pet_ssim: [0.50417662],  total_ssim: [0.94950593], total_l2: [0.02417268], total_loss: [0.30177265]
# Epoch: [ 1],step: [385], mri_ssim: [0.76879454], pet_ssim: [0.62214172],  total_ssim: [1.39093626], total_l2: [0.02518018], total_loss: [0.43490702]
# Epoch: [ 1],step: [390], mri_ssim: [0.48263431], pet_ssim: [0.52466172],  total_ssim: [1.00729609], total_l2: [0.03813440], total_loss: [0.32888293]
# Epoch: [ 1],step: [395], mri_ssim: [0.58922350], pet_ssim: [0.68287057],  total_ssim: [1.27209401], total_l2: [0.02899633], total_loss: [0.40192565]
# Epoch: [ 1],step: [400], mri_ssim: [0.57942992], pet_ssim: [0.65403879],  total_ssim: [1.23346877], total_l2: [0.02570697], total_loss: [0.38803554]
# Epoch: [ 1],step: [405], mri_ssim: [0.38977039], pet_ssim: [0.46275878],  total_ssim: [0.85252917], total_l2: [0.02045720], total_loss: [0.27007881]
# Epoch: [ 1],step: [410], mri_ssim: [0.37642491], pet_ssim: [0.43638170],  total_ssim: [0.81280661], total_l2: [0.02708742], total_loss: [0.26280320]
# Epoch: [ 1],step: [415], mri_ssim: [0.46116585], pet_ssim: [0.66398126],  total_ssim: [1.12514710], total_l2: [0.04230569], total_loss: [0.36715811]
# Epoch: [ 1],step: [420], mri_ssim: [0.33667958], pet_ssim: [0.49016535],  total_ssim: [0.82684493], total_l2: [0.04210805], total_loss: [0.27752912]
# Epoch: [ 1],step: [425], mri_ssim: [0.33805275], pet_ssim: [0.44717371],  total_ssim: [0.78522646], total_l2: [0.04215250], total_loss: [0.26507470]
# Epoch: [ 1],step: [430], mri_ssim: [0.34486365], pet_ssim: [0.46972632],  total_ssim: [0.81458998], total_l2: [0.04829239], total_loss: [0.27818167]
# Epoch: [ 1],step: [435], mri_ssim: [0.35159683], pet_ssim: [0.49792260],  total_ssim: [0.84951943], total_l2: [0.04335712], total_loss: [0.28520581]
# Epoch: [ 1],step: [440], mri_ssim: [0.34894741], pet_ssim: [0.50296032],  total_ssim: [0.85190773], total_l2: [0.03767759], total_loss: [0.28194663]
# Epoch: [ 1],step: [445], mri_ssim: [0.31999648], pet_ssim: [0.54349804],  total_ssim: [0.86349452], total_l2: [0.04111032], total_loss: [0.28782558]
# Epoch: [ 1],step: [450], mri_ssim: [0.27868181], pet_ssim: [0.52821463],  total_ssim: [0.80689645], total_l2: [0.04336792], total_loss: [0.27242649]
# Epoch: [ 1],step: [455], mri_ssim: [0.25779068], pet_ssim: [0.54633033],  total_ssim: [0.80412102], total_l2: [0.04609535], total_loss: [0.27350307]
# Epoch: [ 1],step: [460], mri_ssim: [0.24971175], pet_ssim: [0.53522134],  total_ssim: [0.78493309], total_l2: [0.04448221], total_loss: [0.26661748]
# Epoch: [ 1],step: [465], mri_ssim: [0.30855381], pet_ssim: [0.52235126],  total_ssim: [0.83090508], total_l2: [0.04496721], total_loss: [0.28074858]
# Epoch: [ 1],step: [470], mri_ssim: [0.33682775], pet_ssim: [0.51573443],  total_ssim: [0.85256219], total_l2: [0.05158105], total_loss: [0.29187539]
# Epoch: [ 1],step: [475], mri_ssim: [0.32265460], pet_ssim: [0.52767891],  total_ssim: [0.85033351], total_l2: [0.04751899], total_loss: [0.28836337]
# Epoch: [ 1],step: [480], mri_ssim: [0.32962072], pet_ssim: [0.56677103],  total_ssim: [0.89639175], total_l2: [0.04999783], total_loss: [0.30391601]
# Epoch: [ 1],step: [485], mri_ssim: [0.34820807], pet_ssim: [0.56408715],  total_ssim: [0.91229522], total_l2: [0.05493019], total_loss: [0.31213972]
# Epoch: [ 1],step: [490], mri_ssim: [0.31136930], pet_ssim: [0.55405098],  total_ssim: [0.86542028], total_l2: [0.04857464], total_loss: [0.29362833]
# Epoch: [ 1],step: [495], mri_ssim: [0.29197800], pet_ssim: [0.52426797],  total_ssim: [0.81624597], total_l2: [0.05161946], total_loss: [0.28100744]
# Epoch: [ 1],step: [500], mri_ssim: [0.28015065], pet_ssim: [0.55148256],  total_ssim: [0.83163321], total_l2: [0.05017500], total_loss: [0.28461248]
# Epoch: [ 1],step: [505], mri_ssim: [0.25180924], pet_ssim: [0.53563505],  total_ssim: [0.78744429], total_l2: [0.04947312], total_loss: [0.27086449]
# Epoch: [ 1],step: [510], mri_ssim: [0.29537141], pet_ssim: [0.63588846],  total_ssim: [0.93125987], total_l2: [0.05244683], total_loss: [0.31609076]
# Epoch: [ 1],step: [515], mri_ssim: [0.29560548], pet_ssim: [0.56978089],  total_ssim: [0.86538637], total_l2: [0.05081525], total_loss: [0.29518661]
# Epoch: [ 1],step: [520], mri_ssim: [0.28257096], pet_ssim: [0.52365410],  total_ssim: [0.80622506], total_l2: [0.05249195], total_loss: [0.27861190]
# Epoch: [ 1],step: [525], mri_ssim: [0.30150110], pet_ssim: [0.50113374],  total_ssim: [0.80263484], total_l2: [0.04946344], total_loss: [0.27541485]
# Epoch: [ 1],step: [530], mri_ssim: [0.29169047], pet_ssim: [0.47726285],  total_ssim: [0.76895332], total_l2: [0.05111923], total_loss: [0.26646948]
# Epoch: [ 1],step: [535], mri_ssim: [0.28359723], pet_ssim: [0.45151246],  total_ssim: [0.73510969], total_l2: [0.04500084], total_loss: [0.25203350]
# Epoch: [ 1],step: [540], mri_ssim: [0.26455235], pet_ssim: [0.43250340],  total_ssim: [0.69705576], total_l2: [0.04382629], total_loss: [0.23979515]
# Epoch: [ 1],step: [545], mri_ssim: [0.25744283], pet_ssim: [0.39967823],  total_ssim: [0.65712106], total_l2: [0.04328705], total_loss: [0.22743726]
# Epoch: [ 1],step: [550], mri_ssim: [0.22043490], pet_ssim: [0.40155756],  total_ssim: [0.62199247], total_l2: [0.03905336], total_loss: [0.21393511]
# Epoch: [ 2],step: [555], mri_ssim: [0.39557844], pet_ssim: [0.50081915],  total_ssim: [0.89639759], total_l2: [0.02395285], total_loss: [0.28568628]
# Epoch: [ 2],step: [560], mri_ssim: [0.32659149], pet_ssim: [0.36527014],  total_ssim: [0.69186163], total_l2: [0.01835605], total_loss: [0.22040772]
# Epoch: [ 2],step: [565], mri_ssim: [0.31349814], pet_ssim: [0.43426150],  total_ssim: [0.74775964], total_l2: [0.02496582], total_loss: [0.24180399]
# Epoch: [ 2],step: [570], mri_ssim: [0.33792502], pet_ssim: [0.39711750],  total_ssim: [0.73504251], total_l2: [0.02433140], total_loss: [0.23754475]
# Epoch: [ 2],step: [575], mri_ssim: [0.36680889], pet_ssim: [0.44330621],  total_ssim: [0.81011510], total_l2: [0.02343760], total_loss: [0.25944087]
# Epoch: [ 2],step: [580], mri_ssim: [0.34623849], pet_ssim: [0.40422577],  total_ssim: [0.75046426], total_l2: [0.01995511], total_loss: [0.23910788]
# Epoch: [ 2],step: [585], mri_ssim: [0.33184713], pet_ssim: [0.42142218],  total_ssim: [0.75326931], total_l2: [0.04177311], total_loss: [0.25522199]
# Epoch: [ 2],step: [590], mri_ssim: [0.28250468], pet_ssim: [0.38073677],  total_ssim: [0.66324145], total_l2: [0.03686847], total_loss: [0.22478038]
# Epoch: [ 2],step: [595], mri_ssim: [0.33783758], pet_ssim: [0.33327192],  total_ssim: [0.67110950], total_l2: [0.03543971], total_loss: [0.22614065]
# Epoch: [ 2],step: [600], mri_ssim: [0.29813099], pet_ssim: [0.28568256],  total_ssim: [0.58381355], total_l2: [0.03168517], total_loss: [0.19732369]
# Epoch: [ 2],step: [605], mri_ssim: [0.28557521], pet_ssim: [0.28413409],  total_ssim: [0.56970930], total_l2: [0.02443496], total_loss: [0.18801728]
# Epoch: [ 2],step: [610], mri_ssim: [0.26066840], pet_ssim: [0.26415908],  total_ssim: [0.52482748], total_l2: [0.01907833], total_loss: [0.17080307]
# Epoch: [ 2],step: [615], mri_ssim: [0.25089782], pet_ssim: [0.26019371],  total_ssim: [0.51109153], total_l2: [0.01844888], total_loss: [0.16624168]
# Epoch: [ 2],step: [620], mri_ssim: [0.23986435], pet_ssim: [0.27210748],  total_ssim: [0.51197183], total_l2: [0.01907011], total_loss: [0.16694063]
# Epoch: [ 2],step: [625], mri_ssim: [0.22891694], pet_ssim: [0.25782156],  total_ssim: [0.48673850], total_l2: [0.01784552], total_loss: [0.15851343]
# Epoch: [ 2],step: [630], mri_ssim: [0.28346229], pet_ssim: [0.36364096],  total_ssim: [0.64710325], total_l2: [0.01692232], total_loss: [0.20597662]
# Epoch: [ 2],step: [635], mri_ssim: [0.26197577], pet_ssim: [0.36412370],  total_ssim: [0.62609947], total_l2: [0.01361206], total_loss: [0.19735830]
# Epoch: [ 2],step: [640], mri_ssim: [0.28524017], pet_ssim: [0.34896779],  total_ssim: [0.63420796], total_l2: [0.02884994], total_loss: [0.21045735]
# Epoch: [ 2],step: [645], mri_ssim: [0.43806762], pet_ssim: [0.53254640],  total_ssim: [0.97061402], total_l2: [0.02891209], total_loss: [0.31142268]
# Epoch: [ 2],step: [650], mri_ssim: [0.30278909], pet_ssim: [0.38881803],  total_ssim: [0.69160712], total_l2: [0.01724895], total_loss: [0.21955641]
# Epoch: [ 2],step: [655], mri_ssim: [0.32132244], pet_ssim: [0.42875302],  total_ssim: [0.75007546], total_l2: [0.02708546], total_loss: [0.24398246]
# Epoch: [ 2],step: [660], mri_ssim: [0.25425291], pet_ssim: [0.32875776],  total_ssim: [0.58301067], total_l2: [0.02175706], total_loss: [0.19013315]
# Epoch: [ 2],step: [665], mri_ssim: [0.46734941], pet_ssim: [0.45377648],  total_ssim: [0.92112589], total_l2: [0.01926714], total_loss: [0.28982478]
# Epoch: [ 2],step: [670], mri_ssim: [0.38934046], pet_ssim: [0.46074057],  total_ssim: [0.85008103], total_l2: [0.02453687], total_loss: [0.27220014]
# Epoch: [ 2],step: [675], mri_ssim: [0.27144462], pet_ssim: [0.33679914],  total_ssim: [0.60824376], total_l2: [0.01642433], total_loss: [0.19397017]
# Epoch: [ 2],step: [680], mri_ssim: [0.25680876], pet_ssim: [0.30659980],  total_ssim: [0.56340855], total_l2: [0.02652979], total_loss: [0.18759343]
# Epoch: [ 2],step: [685], mri_ssim: [0.30158532], pet_ssim: [0.39635807],  total_ssim: [0.69794339], total_l2: [0.02484375], total_loss: [0.22677365]
# Epoch: [ 2],step: [690], mri_ssim: [0.29269403], pet_ssim: [0.40990061],  total_ssim: [0.70259464], total_l2: [0.02907607], total_loss: [0.23113164]
# Epoch: [ 2],step: [695], mri_ssim: [0.25454068], pet_ssim: [0.44512177],  total_ssim: [0.69966245], total_l2: [0.04181756], total_loss: [0.23917103]
# Epoch: [ 2],step: [700], mri_ssim: [0.26950806], pet_ssim: [0.41994214],  total_ssim: [0.68945020], total_l2: [0.04154848], total_loss: [0.23591901]
# Epoch: [ 2],step: [705], mri_ssim: [0.26381075], pet_ssim: [0.40819848],  total_ssim: [0.67200923], total_l2: [0.04596202], total_loss: [0.23377618]
# Epoch: [ 2],step: [710], mri_ssim: [0.26618451], pet_ssim: [0.42854643],  total_ssim: [0.69473094], total_l2: [0.04332151], total_loss: [0.23874435]
# Epoch: [ 2],step: [715], mri_ssim: [0.25568575], pet_ssim: [0.42328846],  total_ssim: [0.67897421], total_l2: [0.03946129], total_loss: [0.23131518]
# Epoch: [ 2],step: [720], mri_ssim: [0.24673349], pet_ssim: [0.47230202],  total_ssim: [0.71903551], total_l2: [0.03801739], total_loss: [0.24232283]
# Epoch: [ 2],step: [725], mri_ssim: [0.22842044], pet_ssim: [0.49222159],  total_ssim: [0.72064203], total_l2: [0.04025247], total_loss: [0.24436934]
# Epoch: [ 2],step: [730], mri_ssim: [0.21466851], pet_ssim: [0.50271535],  total_ssim: [0.71738386], total_l2: [0.04325470], total_loss: [0.24549346]
# Epoch: [ 2],step: [735], mri_ssim: [0.19052529], pet_ssim: [0.49910104],  total_ssim: [0.68962634], total_l2: [0.04492161], total_loss: [0.23833305]
# Epoch: [ 2],step: [740], mri_ssim: [0.17408752], pet_ssim: [0.50359225],  total_ssim: [0.67767978], total_l2: [0.04532224], total_loss: [0.23502952]
# Epoch: [ 2],step: [745], mri_ssim: [0.30541372], pet_ssim: [0.48731989],  total_ssim: [0.79273361], total_l2: [0.04714604], total_loss: [0.27082232]
# Epoch: [ 2],step: [750], mri_ssim: [0.34083837], pet_ssim: [0.55681628],  total_ssim: [0.89765465], total_l2: [0.04662682], total_loss: [0.30193520]
# Epoch: [ 2],step: [755], mri_ssim: [0.31156123], pet_ssim: [0.53725636],  total_ssim: [0.84881759], total_l2: [0.04649246], total_loss: [0.28719002]
# Epoch: [ 2],step: [760], mri_ssim: [0.29628742], pet_ssim: [0.53249347],  total_ssim: [0.82878089], total_l2: [0.04298507], total_loss: [0.27872384]
# Epoch: [ 2],step: [765], mri_ssim: [0.28368813], pet_ssim: [0.52437639],  total_ssim: [0.80806452], total_l2: [0.05047609], total_loss: [0.27775264]
# Epoch: [ 2],step: [770], mri_ssim: [0.24896693], pet_ssim: [0.48714304],  total_ssim: [0.73610997], total_l2: [0.05073404], total_loss: [0.25634682]
# Epoch: [ 2],step: [775], mri_ssim: [0.22825015], pet_ssim: [0.49548578],  total_ssim: [0.72373593], total_l2: [0.05228643], total_loss: [0.25372130]
# Epoch: [ 2],step: [780], mri_ssim: [0.19733453], pet_ssim: [0.49470609],  total_ssim: [0.69204062], total_l2: [0.04786321], total_loss: [0.24111645]
# Epoch: [ 2],step: [785], mri_ssim: [0.30331182], pet_ssim: [0.68900764],  total_ssim: [0.99231946], total_l2: [0.05174465], total_loss: [0.33391708]
# Epoch: [ 2],step: [790], mri_ssim: [0.30646926], pet_ssim: [0.62323415],  total_ssim: [0.92970341], total_l2: [0.05298428], total_loss: [0.31600001]
# Epoch: [ 2],step: [795], mri_ssim: [0.25102228], pet_ssim: [0.53506219],  total_ssim: [0.78608447], total_l2: [0.05104752], total_loss: [0.27155861]
# Epoch: [ 2],step: [800], mri_ssim: [0.24345988], pet_ssim: [0.47858268],  total_ssim: [0.72204256], total_l2: [0.05218630], total_loss: [0.25314319]
# Epoch: [ 2],step: [805], mri_ssim: [0.26698101], pet_ssim: [0.47196347],  total_ssim: [0.73894447], total_l2: [0.04737568], total_loss: [0.25484633]
# Epoch: [ 2],step: [810], mri_ssim: [0.27336007], pet_ssim: [0.44585788],  total_ssim: [0.71921796], total_l2: [0.04864220], total_loss: [0.24981494]
# Epoch: [ 2],step: [815], mri_ssim: [0.24185306], pet_ssim: [0.42295027],  total_ssim: [0.66480333], total_l2: [0.04649975], total_loss: [0.23199083]
# Epoch: [ 2],step: [820], mri_ssim: [0.22206461], pet_ssim: [0.39595020],  total_ssim: [0.61801481], total_l2: [0.04216044], total_loss: [0.21491677]
# Epoch: [ 2],step: [825], mri_ssim: [0.19901061], pet_ssim: [0.37638497],  total_ssim: [0.57539558], total_l2: [0.04199167], total_loss: [0.20201285]
# Epoch: [ 2],step: [830], mri_ssim: [0.17200100], pet_ssim: [0.37523186],  total_ssim: [0.54723287], total_l2: [0.03435209], total_loss: [0.18821633]
# Epoch: [ 3],step: [835], mri_ssim: [0.25548065], pet_ssim: [0.32150471],  total_ssim: [0.57698536], total_l2: [0.01414149], total_loss: [0.18299466]
# Epoch: [ 3],step: [840], mri_ssim: [0.28681648], pet_ssim: [0.40619564],  total_ssim: [0.69301212], total_l2: [0.02692129], total_loss: [0.22674854]
# Epoch: [ 3],step: [845], mri_ssim: [0.26699084], pet_ssim: [0.31635749],  total_ssim: [0.58334833], total_l2: [0.01563209], total_loss: [0.18594697]
# Epoch: [ 3],step: [850], mri_ssim: [0.27988195], pet_ssim: [0.46445179],  total_ssim: [0.74433374], total_l2: [0.02129325], total_loss: [0.23820540]
# Epoch: [ 3],step: [855], mri_ssim: [0.32970941], pet_ssim: [0.38798749],  total_ssim: [0.71769691], total_l2: [0.01917573], total_loss: [0.22873209]
# Epoch: [ 3],step: [860], mri_ssim: [0.34066403], pet_ssim: [0.39142168],  total_ssim: [0.73208570], total_l2: [0.03734091], total_loss: [0.24576436]
# Epoch: [ 3],step: [865], mri_ssim: [0.29472750], pet_ssim: [0.36642087],  total_ssim: [0.66114837], total_l2: [0.04377972], total_loss: [0.22899032]
# Epoch: [ 3],step: [870], mri_ssim: [0.23401773], pet_ssim: [0.33942664],  total_ssim: [0.57344437], total_l2: [0.03598936], total_loss: [0.19722587]
# Epoch: [ 3],step: [875], mri_ssim: [0.30285788], pet_ssim: [0.28883153],  total_ssim: [0.59168941], total_l2: [0.03242964], total_loss: [0.20020758]
# Epoch: [ 3],step: [880], mri_ssim: [0.26615953], pet_ssim: [0.26266289],  total_ssim: [0.52882242], total_l2: [0.02512786], total_loss: [0.17623623]
# Epoch: [ 3],step: [885], mri_ssim: [0.23617423], pet_ssim: [0.24078429],  total_ssim: [0.47695851], total_l2: [0.01901670], total_loss: [0.15639925]
# Epoch: [ 3],step: [890], mri_ssim: [0.21760082], pet_ssim: [0.22816253],  total_ssim: [0.44576335], total_l2: [0.01717556], total_loss: [0.14575191]
# Epoch: [ 3],step: [895], mri_ssim: [0.20360714], pet_ssim: [0.23803210],  total_ssim: [0.44163924], total_l2: [0.01745188], total_loss: [0.14470810]
# Epoch: [ 3],step: [900], mri_ssim: [0.22248840], pet_ssim: [0.25037408],  total_ssim: [0.47286248], total_l2: [0.01765076], total_loss: [0.15421429]
# Epoch: [ 3],step: [905], mri_ssim: [0.24727774], pet_ssim: [0.40373385],  total_ssim: [0.65101159], total_l2: [0.01922842], total_loss: [0.20876338]
# Epoch: [ 3],step: [910], mri_ssim: [0.30229753], pet_ssim: [0.41053760],  total_ssim: [0.71283513], total_l2: [0.02762024], total_loss: [0.23318471]
# Epoch: [ 3],step: [915], mri_ssim: [0.26490593], pet_ssim: [0.33169997],  total_ssim: [0.59660590], total_l2: [0.02054080], total_loss: [0.19336034]
# Epoch: [ 3],step: [920], mri_ssim: [0.20697838], pet_ssim: [0.29394352],  total_ssim: [0.50092191], total_l2: [0.02255942], total_loss: [0.16606817]
# Epoch: [ 3],step: [925], mri_ssim: [0.32340062], pet_ssim: [0.37828732],  total_ssim: [0.70168793], total_l2: [0.02464374], total_loss: [0.22775701]
# Epoch: [ 3],step: [930], mri_ssim: [0.35041606], pet_ssim: [0.47069430],  total_ssim: [0.82111037], total_l2: [0.02815974], total_loss: [0.26604494]
# Epoch: [ 3],step: [935], mri_ssim: [0.26994169], pet_ssim: [0.35143602],  total_ssim: [0.62137771], total_l2: [0.01796360], total_loss: [0.19898784]
# Epoch: [ 3],step: [940], mri_ssim: [0.55534029], pet_ssim: [0.38315070],  total_ssim: [0.93849099], total_l2: [0.01887120], total_loss: [0.29475716]
# Epoch: [ 3],step: [945], mri_ssim: [0.45785606], pet_ssim: [0.42778140],  total_ssim: [0.88563746], total_l2: [0.02325785], total_loss: [0.28197175]
# Epoch: [ 3],step: [950], mri_ssim: [0.30611521], pet_ssim: [0.38439542],  total_ssim: [0.69051063], total_l2: [0.02106833], total_loss: [0.22190103]
# Epoch: [ 3],step: [955], mri_ssim: [0.25477177], pet_ssim: [0.30988216],  total_ssim: [0.56465393], total_l2: [0.02638152], total_loss: [0.18786326]
# Epoch: [ 3],step: [960], mri_ssim: [0.19099361], pet_ssim: [0.24243176],  total_ssim: [0.43342537], total_l2: [0.01455908], total_loss: [0.14021897]
# Epoch: [ 3],step: [965], mri_ssim: [0.23498631], pet_ssim: [0.31523156],  total_ssim: [0.55021787], total_l2: [0.01851060], total_loss: [0.17802279]
# Epoch: [ 3],step: [970], mri_ssim: [0.26572907], pet_ssim: [0.47094250],  total_ssim: [0.73667157], total_l2: [0.04146923], total_loss: [0.25002995]
# Epoch: [ 3],step: [975], mri_ssim: [0.26619673], pet_ssim: [0.45419896],  total_ssim: [0.72039568], total_l2: [0.04124643], total_loss: [0.24499121]
# Epoch: [ 3],step: [980], mri_ssim: [0.26037395], pet_ssim: [0.41316998],  total_ssim: [0.67354393], total_l2: [0.04123143], total_loss: [0.23092519]
# Epoch: [ 3],step: [985], mri_ssim: [0.23646230], pet_ssim: [0.41463673],  total_ssim: [0.65109903], total_l2: [0.04607436], total_loss: [0.22758177]
# Epoch: [ 3],step: [990], mri_ssim: [0.23772287], pet_ssim: [0.41215265],  total_ssim: [0.64987552], total_l2: [0.04079866], total_loss: [0.22352172]
# Epoch: [ 3],step: [995], mri_ssim: [0.22790784], pet_ssim: [0.43833637],  total_ssim: [0.66624421], total_l2: [0.03636463], total_loss: [0.22532851]
# Epoch: [ 3],step: [1000], mri_ssim: [0.21365571], pet_ssim: [0.47760546],  total_ssim: [0.69126117], total_l2: [0.03939507], total_loss: [0.23495491]
# Epoch: [ 3],step: [1005], mri_ssim: [0.18857646], pet_ssim: [0.48149449],  total_ssim: [0.67007095], total_l2: [0.04304767], total_loss: [0.23115467]
# Epoch: [ 3],step: [1010], mri_ssim: [0.16985095], pet_ssim: [0.49375319],  total_ssim: [0.66360414], total_l2: [0.04616723], total_loss: [0.23139831]
# Epoch: [ 3],step: [1015], mri_ssim: [0.15930301], pet_ssim: [0.47334540],  total_ssim: [0.63264841], total_l2: [0.04263337], total_loss: [0.21963789]
# Epoch: [ 3],step: [1020], mri_ssim: [0.39070898], pet_ssim: [0.59391224],  total_ssim: [0.98462123], total_l2: [0.04362937], total_loss: [0.32592693]
# Epoch: [ 3],step: [1025], mri_ssim: [0.29509056], pet_ssim: [0.51155901],  total_ssim: [0.80664957], total_l2: [0.04986124], total_loss: [0.27689773]
# Epoch: [ 3],step: [1030], mri_ssim: [0.26842868], pet_ssim: [0.50989479],  total_ssim: [0.77832347], total_l2: [0.04764053], total_loss: [0.26684543]
# Epoch: [ 3],step: [1035], mri_ssim: [0.30148745], pet_ssim: [0.54335469],  total_ssim: [0.84484214], total_l2: [0.04914868], total_loss: [0.28785673]
# Epoch: [ 3],step: [1040], mri_ssim: [0.28312075], pet_ssim: [0.50922501],  total_ssim: [0.79234576], total_l2: [0.05620914], total_loss: [0.27705014]
# Epoch: [ 3],step: [1045], mri_ssim: [0.23907149], pet_ssim: [0.50331205],  total_ssim: [0.74238354], total_l2: [0.04718645], total_loss: [0.25574559]
# Epoch: [ 3],step: [1050], mri_ssim: [0.22643214], pet_ssim: [0.48805630],  total_ssim: [0.71448845], total_l2: [0.05115812], total_loss: [0.25015724]
# Epoch: [ 3],step: [1055], mri_ssim: [0.19477129], pet_ssim: [0.49634206],  total_ssim: [0.69111335], total_l2: [0.05048130], total_loss: [0.24267092]
# Epoch: [ 3],step: [1060], mri_ssim: [0.21197098], pet_ssim: [0.61233377],  total_ssim: [0.82430476], total_l2: [0.05448499], total_loss: [0.28543091]
# Epoch: [ 3],step: [1065], mri_ssim: [0.31454951], pet_ssim: [0.63011467],  total_ssim: [0.94466418], total_l2: [0.04966626], total_loss: [0.31816563]
# Epoch: [ 3],step: [1070], mri_ssim: [0.28138554], pet_ssim: [0.59672725],  total_ssim: [0.87811279], total_l2: [0.04934622], total_loss: [0.29797620]
# Epoch: [ 3],step: [1075], mri_ssim: [0.22929633], pet_ssim: [0.47870064],  total_ssim: [0.70799696], total_l2: [0.05158223], total_loss: [0.24850665]
# Epoch: [ 3],step: [1080], mri_ssim: [0.25746000], pet_ssim: [0.47782969],  total_ssim: [0.73528969], total_l2: [0.04814646], total_loss: [0.25428945]
# Epoch: [ 3],step: [1085], mri_ssim: [0.25173336], pet_ssim: [0.45237601],  total_ssim: [0.70410937], total_l2: [0.05376911], total_loss: [0.24887121]
# Epoch: [ 3],step: [1090], mri_ssim: [0.22152340], pet_ssim: [0.42254317],  total_ssim: [0.64406657], total_l2: [0.04579930], total_loss: [0.22527948]
# Epoch: [ 3],step: [1095], mri_ssim: [0.19839633], pet_ssim: [0.40081000],  total_ssim: [0.59920633], total_l2: [0.04365052], total_loss: [0.21031727]
# Epoch: [ 3],step: [1100], mri_ssim: [0.18948591], pet_ssim: [0.36115825],  total_ssim: [0.55064416], total_l2: [0.04462494], total_loss: [0.19643071]
# Epoch: [ 3],step: [1105], mri_ssim: [0.15512639], pet_ssim: [0.35562456],  total_ssim: [0.51075095], total_l2: [0.03684185], total_loss: [0.17901459]
# Epoch: [ 4],step: [1110], mri_ssim: [0.29640889], pet_ssim: [0.37443757],  total_ssim: [0.67084646], total_l2: [0.02001554], total_loss: [0.21526483]
# Epoch: [ 4],step: [1115], mri_ssim: [0.23151976], pet_ssim: [0.23096651],  total_ssim: [0.46248627], total_l2: [0.01495520], total_loss: [0.14921452]
# Epoch: [ 4],step: [1120], mri_ssim: [0.26921445], pet_ssim: [0.34685516],  total_ssim: [0.61606961], total_l2: [0.02035935], total_loss: [0.19907244]
# Epoch: [ 4],step: [1125], mri_ssim: [0.27356195], pet_ssim: [0.46809506],  total_ssim: [0.74165702], total_l2: [0.02939771], total_loss: [0.24307552]
# Epoch: [ 4],step: [1130], mri_ssim: [0.30222577], pet_ssim: [0.38669717],  total_ssim: [0.68892294], total_l2: [0.01995336], total_loss: [0.22064424]
# Epoch: [ 4],step: [1135], mri_ssim: [0.28238773], pet_ssim: [0.43114507],  total_ssim: [0.71353281], total_l2: [0.02581943], total_loss: [0.23213345]
# Epoch: [ 4],step: [1140], mri_ssim: [0.29640436], pet_ssim: [0.39570653],  total_ssim: [0.69211090], total_l2: [0.03970589], total_loss: [0.23542739]
# Epoch: [ 4],step: [1145], mri_ssim: [0.24585056], pet_ssim: [0.34462285],  total_ssim: [0.59047341], total_l2: [0.03886702], total_loss: [0.20434894]
# Epoch: [ 4],step: [1150], mri_ssim: [0.26144081], pet_ssim: [0.25334340],  total_ssim: [0.51478422], total_l2: [0.03311092], total_loss: [0.17761292]
# Epoch: [ 4],step: [1155], mri_ssim: [0.23223418], pet_ssim: [0.23286736],  total_ssim: [0.46510154], total_l2: [0.02868961], total_loss: [0.15961319]
# Epoch: [ 4],step: [1160], mri_ssim: [0.19934082], pet_ssim: [0.21598434],  total_ssim: [0.41532516], total_l2: [0.02077800], total_loss: [0.13914216]
# Epoch: [ 4],step: [1165], mri_ssim: [0.19791687], pet_ssim: [0.21265614],  total_ssim: [0.41057301], total_l2: [0.01755389], total_loss: [0.13545963]
# Epoch: [ 4],step: [1170], mri_ssim: [0.19177276], pet_ssim: [0.21643221],  total_ssim: [0.40820497], total_l2: [0.01757579], total_loss: [0.13476455]
# Epoch: [ 4],step: [1175], mri_ssim: [0.18551892], pet_ssim: [0.22188014],  total_ssim: [0.40739906], total_l2: [0.01807313], total_loss: [0.13487092]
# Epoch: [ 4],step: [1180], mri_ssim: [0.26531160], pet_ssim: [0.41177857],  total_ssim: [0.67709017], total_l2: [0.02482367], total_loss: [0.22050363]
# Epoch: [ 4],step: [1185], mri_ssim: [0.26146746], pet_ssim: [0.30318576],  total_ssim: [0.56465322], total_l2: [0.02126570], total_loss: [0.18428196]
# Epoch: [ 4],step: [1190], mri_ssim: [0.22192466], pet_ssim: [0.30225039],  total_ssim: [0.52417505], total_l2: [0.01562445], total_loss: [0.16818963]
# Epoch: [ 4],step: [1195], mri_ssim: [0.23971158], pet_ssim: [0.28743827],  total_ssim: [0.52714986], total_l2: [0.02354904], total_loss: [0.17462930]
# Epoch: [ 4],step: [1200], mri_ssim: [0.28134882], pet_ssim: [0.37555641],  total_ssim: [0.65690523], total_l2: [0.02433768], total_loss: [0.21410796]
# Epoch: [ 4],step: [1205], mri_ssim: [0.21095544], pet_ssim: [0.27783602],  total_ssim: [0.48879147], total_l2: [0.01572442], total_loss: [0.15764454]
# Epoch: [ 4],step: [1210], mri_ssim: [0.27213240], pet_ssim: [0.37412894],  total_ssim: [0.64626133], total_l2: [0.02456079], total_loss: [0.21107097]
# Epoch: [ 4],step: [1215], mri_ssim: [0.23403686], pet_ssim: [0.28647852],  total_ssim: [0.52051538], total_l2: [0.02318369], total_loss: [0.17238320]
# Epoch: [ 4],step: [1220], mri_ssim: [0.56216037], pet_ssim: [0.34770602],  total_ssim: [0.90986639], total_l2: [0.02469791], total_loss: [0.29024845]
# Epoch: [ 4],step: [1225], mri_ssim: [0.33272910], pet_ssim: [0.43547231],  total_ssim: [0.76820141], total_l2: [0.03004996], total_loss: [0.25149542]
# Epoch: [ 4],step: [1230], mri_ssim: [0.19012296], pet_ssim: [0.26704454],  total_ssim: [0.45716751], total_l2: [0.01365452], total_loss: [0.14670841]
# Epoch: [ 4],step: [1235], mri_ssim: [0.20113897], pet_ssim: [0.25876230],  total_ssim: [0.45990127], total_l2: [0.02124790], total_loss: [0.15284392]
# Epoch: [ 4],step: [1240], mri_ssim: [0.28200155], pet_ssim: [0.36006320],  total_ssim: [0.64206475], total_l2: [0.02903128], total_loss: [0.21294132]
# Epoch: [ 4],step: [1245], mri_ssim: [0.15749550], pet_ssim: [0.41113204],  total_ssim: [0.56862754], total_l2: [0.04090775], total_loss: [0.19922370]
# Epoch: [ 4],step: [1250], mri_ssim: [0.20516455], pet_ssim: [0.41088086],  total_ssim: [0.61604542], total_l2: [0.04092001], total_loss: [0.21345764]
# Epoch: [ 4],step: [1255], mri_ssim: [0.20127189], pet_ssim: [0.37969863],  total_ssim: [0.58097053], total_l2: [0.03942123], total_loss: [0.20188603]
# Epoch: [ 4],step: [1260], mri_ssim: [0.22447300], pet_ssim: [0.39605457],  total_ssim: [0.62052757], total_l2: [0.04607678], total_loss: [0.21841201]
# Epoch: [ 4],step: [1265], mri_ssim: [0.23368680], pet_ssim: [0.41655076],  total_ssim: [0.65023756], total_l2: [0.04206877], total_loss: [0.22451942]
# Epoch: [ 4],step: [1270], mri_ssim: [0.22309935], pet_ssim: [0.40620726],  total_ssim: [0.62930661], total_l2: [0.03747918], total_loss: [0.21502742]
# Epoch: [ 4],step: [1275], mri_ssim: [0.20230287], pet_ssim: [0.45350325],  total_ssim: [0.65580612], total_l2: [0.03918725], total_loss: [0.22417292]
# Epoch: [ 4],step: [1280], mri_ssim: [0.18585861], pet_ssim: [0.47573447],  total_ssim: [0.66159308], total_l2: [0.04105657], total_loss: [0.22721754]
# Epoch: [ 4],step: [1285], mri_ssim: [0.16553855], pet_ssim: [0.47918975],  total_ssim: [0.64472830], total_l2: [0.04271981], total_loss: [0.22332238]
# Epoch: [ 4],step: [1290], mri_ssim: [0.13843995], pet_ssim: [0.46642482],  total_ssim: [0.60486478], total_l2: [0.04345059], total_loss: [0.21187486]
# Epoch: [ 4],step: [1295], mri_ssim: [0.26838571], pet_ssim: [0.51965487],  total_ssim: [0.78804058], total_l2: [0.04295569], total_loss: [0.26648116]
# Epoch: [ 4],step: [1300], mri_ssim: [0.24967682], pet_ssim: [0.45324892],  total_ssim: [0.70292574], total_l2: [0.04700730], total_loss: [0.24378283]
# Epoch: [ 4],step: [1305], mri_ssim: [0.27811545], pet_ssim: [0.50651318],  total_ssim: [0.78462863], total_l2: [0.04456932], total_loss: [0.26658711]
# Epoch: [ 4],step: [1310], mri_ssim: [0.27680600], pet_ssim: [0.51644003],  total_ssim: [0.79324603], total_l2: [0.04610394], total_loss: [0.27024660]
# Epoch: [ 4],step: [1315], mri_ssim: [0.27692342], pet_ssim: [0.51926535],  total_ssim: [0.79618877], total_l2: [0.04615356], total_loss: [0.27116412]
# Epoch: [ 4],step: [1320], mri_ssim: [0.23948592], pet_ssim: [0.51275480],  total_ssim: [0.75224072], total_l2: [0.05035105], total_loss: [0.26091796]
# Epoch: [ 4],step: [1325], mri_ssim: [0.21049583], pet_ssim: [0.47267640],  total_ssim: [0.68317223], total_l2: [0.05174691], total_loss: [0.24117452]
# Epoch: [ 4],step: [1330], mri_ssim: [0.17905033], pet_ssim: [0.47467732],  total_ssim: [0.65372765], total_l2: [0.05140034], total_loss: [0.23209855]
# Epoch: [ 4],step: [1335], mri_ssim: [0.16435128], pet_ssim: [0.47230756],  total_ssim: [0.63665885], total_l2: [0.04618403], total_loss: [0.22332647]
# Epoch: [ 4],step: [1340], mri_ssim: [0.28398657], pet_ssim: [0.63236308],  total_ssim: [0.91634965], total_l2: [0.04917859], total_loss: [0.30932993]
# Epoch: [ 4],step: [1345], mri_ssim: [0.25478017], pet_ssim: [0.56538641],  total_ssim: [0.82016659], total_l2: [0.04990117], total_loss: [0.28098080]
# Epoch: [ 4],step: [1350], mri_ssim: [0.20400333], pet_ssim: [0.49359834],  total_ssim: [0.69760168], total_l2: [0.04962362], total_loss: [0.24401703]
# Epoch: [ 4],step: [1355], mri_ssim: [0.23347259], pet_ssim: [0.47037876],  total_ssim: [0.70385134], total_l2: [0.04908742], total_loss: [0.24551661]
# Epoch: [ 4],step: [1360], mri_ssim: [0.23455101], pet_ssim: [0.45528483],  total_ssim: [0.68983585], total_l2: [0.04699700], total_loss: [0.23984867]
# Epoch: [ 4],step: [1365], mri_ssim: [0.22303259], pet_ssim: [0.43117052],  total_ssim: [0.65420312], total_l2: [0.04596341], total_loss: [0.22843534]
# Epoch: [ 4],step: [1370], mri_ssim: [0.20110881], pet_ssim: [0.40702939],  total_ssim: [0.60813820], total_l2: [0.04603756], total_loss: [0.21466777]
# Epoch: [ 4],step: [1375], mri_ssim: [0.18650007], pet_ssim: [0.36650676],  total_ssim: [0.55300683], total_l2: [0.04294537], total_loss: [0.19596380]
# Epoch: [ 4],step: [1380], mri_ssim: [0.15139818], pet_ssim: [0.34938210],  total_ssim: [0.50078028], total_l2: [0.03957991], total_loss: [0.17794003]
# Epoch: [ 4],step: [1385], mri_ssim: [0.15368640], pet_ssim: [0.37857246],  total_ssim: [0.53225887], total_l2: [0.03243718], total_loss: [0.18238370]
# Epoch: [ 5],step: [1390], mri_ssim: [0.21449596], pet_ssim: [0.25353849],  total_ssim: [0.46803445], total_l2: [0.01271283], total_loss: [0.14930932]
# Epoch: [ 5],step: [1395], mri_ssim: [0.26967597], pet_ssim: [0.40175664],  total_ssim: [0.67143261], total_l2: [0.02320733], total_loss: [0.21767493]
# Epoch: [ 5],step: [1400], mri_ssim: [0.23801619], pet_ssim: [0.26648426],  total_ssim: [0.50450045], total_l2: [0.01938316], total_loss: [0.16491835]
# Epoch: [ 5],step: [1405], mri_ssim: [0.25976038], pet_ssim: [0.44095922],  total_ssim: [0.70071959], total_l2: [0.02228846], total_loss: [0.22581780]
# Epoch: [ 5],step: [1410], mri_ssim: [0.29878277], pet_ssim: [0.36509371],  total_ssim: [0.66387647], total_l2: [0.01749169], total_loss: [0.21140712]
# Epoch: [ 5],step: [1415], mri_ssim: [0.32462156], pet_ssim: [0.37985551],  total_ssim: [0.70447707], total_l2: [0.04169951], total_loss: [0.24053279]
# Epoch: [ 5],step: [1420], mri_ssim: [0.25442851], pet_ssim: [0.34052718],  total_ssim: [0.59495568], total_l2: [0.03728902], total_loss: [0.20458902]
# Epoch: [ 5],step: [1425], mri_ssim: [0.21254170], pet_ssim: [0.27266145],  total_ssim: [0.48520315], total_l2: [0.03262467], total_loss: [0.16839822]
# Epoch: [ 5],step: [1430], mri_ssim: [0.24043709], pet_ssim: [0.23150849],  total_ssim: [0.47194558], total_l2: [0.03057919], total_loss: [0.16298911]
# Epoch: [ 5],step: [1435], mri_ssim: [0.20224655], pet_ssim: [0.21718693],  total_ssim: [0.41943347], total_l2: [0.02291297], total_loss: [0.14186913]
# Epoch: [ 5],step: [1440], mri_ssim: [0.19316614], pet_ssim: [0.20933783],  total_ssim: [0.40250397], total_l2: [0.01728985], total_loss: [0.13285409]
# Epoch: [ 5],step: [1445], mri_ssim: [0.18115133], pet_ssim: [0.20089769],  total_ssim: [0.38204902], total_l2: [0.01650568], total_loss: [0.12616868]
# Epoch: [ 5],step: [1450], mri_ssim: [0.16799772], pet_ssim: [0.20673430],  total_ssim: [0.37473202], total_l2: [0.01754751], total_loss: [0.12470287]
# Epoch: [ 5],step: [1455], mri_ssim: [0.16783011], pet_ssim: [0.19476849],  total_ssim: [0.36259860], total_l2: [0.01705686], total_loss: [0.12071939]
# Epoch: [ 5],step: [1460], mri_ssim: [0.17563236], pet_ssim: [0.31073797],  total_ssim: [0.48637033], total_l2: [0.01742039], total_loss: [0.15810537]
# Epoch: [ 5],step: [1465], mri_ssim: [0.20581818], pet_ssim: [0.29668987],  total_ssim: [0.50250804], total_l2: [0.02140565], total_loss: [0.16573638]
# Epoch: [ 5],step: [1470], mri_ssim: [0.21420044], pet_ssim: [0.26845551],  total_ssim: [0.48265594], total_l2: [0.02649436], total_loss: [0.16334283]
# Epoch: [ 5],step: [1475], mri_ssim: [0.20555174], pet_ssim: [0.31242621],  total_ssim: [0.51797795], total_l2: [0.02644122], total_loss: [0.17390224]
# Epoch: [ 5],step: [1480], mri_ssim: [0.23669171], pet_ssim: [0.29170913],  total_ssim: [0.52840084], total_l2: [0.01830583], total_loss: [0.17133433]
# Epoch: [ 5],step: [1485], mri_ssim: [0.30330086], pet_ssim: [0.42317969],  total_ssim: [0.72648054], total_l2: [0.03346837], total_loss: [0.24137203]
# Epoch: [ 5],step: [1490], mri_ssim: [0.21796513], pet_ssim: [0.30233335],  total_ssim: [0.52029848], total_l2: [0.01897474], total_loss: [0.16937186]
# Epoch: [ 5],step: [1495], mri_ssim: [0.52350605], pet_ssim: [0.36342585],  total_ssim: [0.88693190], total_l2: [0.01675752], total_loss: [0.27780983]
# Epoch: [ 5],step: [1500], mri_ssim: [0.47193468], pet_ssim: [0.35608745],  total_ssim: [0.82802212], total_l2: [0.02320582], total_loss: [0.26465073]
# Epoch: [ 5],step: [1505], mri_ssim: [0.23376340], pet_ssim: [0.29551047],  total_ssim: [0.52927387], total_l2: [0.01969058], total_loss: [0.17256558]
# Epoch: [ 5],step: [1510], mri_ssim: [0.25468421], pet_ssim: [0.28934264],  total_ssim: [0.54402685], total_l2: [0.02841917], total_loss: [0.18310149]
# Epoch: [ 5],step: [1515], mri_ssim: [0.18125689], pet_ssim: [0.20451069],  total_ssim: [0.38576758], total_l2: [0.01284278], total_loss: [0.12472022]
# Epoch: [ 5],step: [1520], mri_ssim: [0.20500600], pet_ssim: [0.25284123],  total_ssim: [0.45784724], total_l2: [0.01698459], total_loss: [0.14924340]
# Epoch: [ 5],step: [1525], mri_ssim: [0.17160475], pet_ssim: [0.37335116],  total_ssim: [0.54495591], total_l2: [0.04129482], total_loss: [0.19239315]
# Epoch: [ 5],step: [1530], mri_ssim: [0.21238804], pet_ssim: [0.40169585],  total_ssim: [0.61408389], total_l2: [0.04074341], total_loss: [0.21274556]
# Epoch: [ 5],step: [1535], mri_ssim: [0.22833586], pet_ssim: [0.39421046],  total_ssim: [0.62254632], total_l2: [0.04204690], total_loss: [0.21619673]
# Epoch: [ 5],step: [1540], mri_ssim: [0.20855069], pet_ssim: [0.40285313],  total_ssim: [0.61140382], total_l2: [0.04429587], total_loss: [0.21442826]
# Epoch: [ 5],step: [1545], mri_ssim: [0.21242130], pet_ssim: [0.40083504],  total_ssim: [0.61325634], total_l2: [0.03933351], total_loss: [0.21151036]
# Epoch: [ 5],step: [1550], mri_ssim: [0.20846641], pet_ssim: [0.44466811],  total_ssim: [0.65313452], total_l2: [0.03687318], total_loss: [0.22175159]
# Epoch: [ 5],step: [1555], mri_ssim: [0.19093227], pet_ssim: [0.47349799],  total_ssim: [0.66443026], total_l2: [0.03896281], total_loss: [0.22660306]
# Epoch: [ 5],step: [1560], mri_ssim: [0.16070747], pet_ssim: [0.47006094],  total_ssim: [0.63076842], total_l2: [0.04287070], total_loss: [0.21924002]
# Epoch: [ 5],step: [1565], mri_ssim: [0.13232207], pet_ssim: [0.46897709],  total_ssim: [0.60129917], total_l2: [0.04512938], total_loss: [0.21198033]
# Epoch: [ 5],step: [1570], mri_ssim: [0.11294580], pet_ssim: [0.44706130],  total_ssim: [0.56000710], total_l2: [0.04100644], total_loss: [0.19670664]
# Epoch: [ 5],step: [1575], mri_ssim: [0.21496844], pet_ssim: [0.44010037],  total_ssim: [0.65506881], total_l2: [0.04298368], total_loss: [0.22660923]
# Epoch: [ 5],step: [1580], mri_ssim: [0.27144659], pet_ssim: [0.48768055],  total_ssim: [0.75912714], total_l2: [0.04705781], total_loss: [0.26067862]
# Epoch: [ 5],step: [1585], mri_ssim: [0.25083935], pet_ssim: [0.49323583],  total_ssim: [0.74407518], total_l2: [0.04537149], total_loss: [0.25498262]
# Epoch: [ 5],step: [1590], mri_ssim: [0.25932992], pet_ssim: [0.51197094],  total_ssim: [0.77130085], total_l2: [0.04440370], total_loss: [0.26247287]
# Epoch: [ 5],step: [1595], mri_ssim: [0.26236236], pet_ssim: [0.50690520],  total_ssim: [0.76926756], total_l2: [0.05411021], total_loss: [0.26865742]
# Epoch: [ 5],step: [1600], mri_ssim: [0.21267807], pet_ssim: [0.47384107],  total_ssim: [0.68651915], total_l2: [0.04936446], total_loss: [0.24051088]
# Epoch: [ 5],step: [1605], mri_ssim: [0.18972117], pet_ssim: [0.47507071],  total_ssim: [0.66479188], total_l2: [0.05201628], total_loss: [0.23584896]
# ...
# Epoch: [58],step: [16100], mri_ssim: [0.18255651], pet_ssim: [0.36292827],  total_ssim: [0.54548478], total_l2: [0.03974199], total_loss: [0.19146484]
# Epoch: [58],step: [16105], mri_ssim: [0.15210712], pet_ssim: [0.30241609],  total_ssim: [0.45452321], total_l2: [0.03029911], total_loss: [0.15756634]
# Epoch: [58],step: [16110], mri_ssim: [0.15221906], pet_ssim: [0.18389922],  total_ssim: [0.33611828], total_l2: [0.02507151], total_loss: [0.11838554]
# Epoch: [58],step: [16115], mri_ssim: [0.11915600], pet_ssim: [0.16951895],  total_ssim: [0.28867495], total_l2: [0.01696373], total_loss: [0.09847710]
# Epoch: [58],step: [16120], mri_ssim: [0.10385388], pet_ssim: [0.16915566],  total_ssim: [0.27300954], total_l2: [0.01554341], total_loss: [0.09278325]
# Epoch: [58],step: [16125], mri_ssim: [0.09771395], pet_ssim: [0.15182054],  total_ssim: [0.24953449], total_l2: [0.01469033], total_loss: [0.08514358]
# Epoch: [58],step: [16130], mri_ssim: [0.09144485], pet_ssim: [0.14938366],  total_ssim: [0.24082851], total_l2: [0.01526685], total_loss: [0.08293536]
# Epoch: [58],step: [16135], mri_ssim: [0.08436596], pet_ssim: [0.11653697],  total_ssim: [0.20090294], total_l2: [0.01593328], total_loss: [0.07142418]
# Epoch: [58],step: [16140], mri_ssim: [0.17097020], pet_ssim: [0.27928257],  total_ssim: [0.45025277], total_l2: [0.01917994], total_loss: [0.14850180]
# Epoch: [58],step: [16145], mri_ssim: [0.17553818], pet_ssim: [0.26272911],  total_ssim: [0.43826729], total_l2: [0.02370236], total_loss: [0.14807184]
# Epoch: [58],step: [16150], mri_ssim: [0.16883552], pet_ssim: [0.24353665],  total_ssim: [0.41237217], total_l2: [0.01774847], total_loss: [0.13613558]
# Epoch: [58],step: [16155], mri_ssim: [0.13519323], pet_ssim: [0.23519790],  total_ssim: [0.37039113], total_l2: [0.01923704], total_loss: [0.12458327]
# Epoch: [58],step: [16160], mri_ssim: [0.17911798], pet_ssim: [0.28877139],  total_ssim: [0.46788937], total_l2: [0.02159428], total_loss: [0.15548281]
# Epoch: [58],step: [16165], mri_ssim: [0.20737290], pet_ssim: [0.39715374],  total_ssim: [0.60452664], total_l2: [0.02537200], total_loss: [0.19911839]
# Epoch: [58],step: [16170], mri_ssim: [0.18689638], pet_ssim: [0.26702052],  total_ssim: [0.45391691], total_l2: [0.01415444], total_loss: [0.14608319]
# Epoch: [58],step: [16175], mri_ssim: [0.44770849], pet_ssim: [0.36735392],  total_ssim: [0.81506240], total_l2: [0.01591066], total_loss: [0.25565618]
# Epoch: [58],step: [16180], mri_ssim: [0.37472785], pet_ssim: [0.38832843],  total_ssim: [0.76305628], total_l2: [0.02054317], total_loss: [0.24329711]
# Epoch: [58],step: [16185], mri_ssim: [0.18777406], pet_ssim: [0.32650566],  total_ssim: [0.51427972], total_l2: [0.01808125], total_loss: [0.16694081]
# Epoch: [58],step: [16190], mri_ssim: [0.19302702], pet_ssim: [0.27194107],  total_ssim: [0.46496809], total_l2: [0.02368898], total_loss: [0.15607271]
# Epoch: [58],step: [16195], mri_ssim: [0.15241396], pet_ssim: [0.20787764],  total_ssim: [0.36029160], total_l2: [0.01304570], total_loss: [0.11721948]
# Epoch: [58],step: [16200], mri_ssim: [0.19148421], pet_ssim: [0.26739657],  total_ssim: [0.45888078], total_l2: [0.01601130], total_loss: [0.14887215]
# Epoch: [58],step: [16205], mri_ssim: [0.09989893], pet_ssim: [0.36387545],  total_ssim: [0.46377438], total_l2: [0.03618614], total_loss: [0.16446263]
# Epoch: [58],step: [16210], mri_ssim: [0.12772763], pet_ssim: [0.36185718],  total_ssim: [0.48958480], total_l2: [0.03832217], total_loss: [0.17370096]
# Epoch: [58],step: [16215], mri_ssim: [0.15141797], pet_ssim: [0.36005688],  total_ssim: [0.51147485], total_l2: [0.03886657], total_loss: [0.18064906]
# Epoch: [58],step: [16220], mri_ssim: [0.15954721], pet_ssim: [0.38149726],  total_ssim: [0.54104447], total_l2: [0.04351490], total_loss: [0.19277377]
# Epoch: [58],step: [16225], mri_ssim: [0.16697788], pet_ssim: [0.38286793],  total_ssim: [0.54984581], total_l2: [0.03781585], total_loss: [0.19142485]
# Epoch: [58],step: [16230], mri_ssim: [0.13673794], pet_ssim: [0.42148840],  total_ssim: [0.55822635], total_l2: [0.03534518], total_loss: [0.19220953]
# Epoch: [58],step: [16235], mri_ssim: [0.12476397], pet_ssim: [0.45450902],  total_ssim: [0.57927299], total_l2: [0.03745057], total_loss: [0.19999731]
# Epoch: [58],step: [16240], mri_ssim: [0.10286617], pet_ssim: [0.45833027],  total_ssim: [0.56119645], total_l2: [0.03957853], total_loss: [0.19606391]
# Epoch: [58],step: [16245], mri_ssim: [0.07843435], pet_ssim: [0.46183574],  total_ssim: [0.54027009], total_l2: [0.04234077], total_loss: [0.19171956]
# Epoch: [58],step: [16250], mri_ssim: [0.06278849], pet_ssim: [0.41244221],  total_ssim: [0.47523069], total_l2: [0.03576902], total_loss: [0.16760753]
# Epoch: [58],step: [16255], mri_ssim: [0.11755860], pet_ssim: [0.44693691],  total_ssim: [0.56449550], total_l2: [0.03919009], total_loss: [0.19678172]
# Epoch: [58],step: [16260], mri_ssim: [0.19006348], pet_ssim: [0.47017497],  total_ssim: [0.66023844], total_l2: [0.04825401], total_loss: [0.23184934]
# Epoch: [58],step: [16265], mri_ssim: [0.16059637], pet_ssim: [0.46861213],  total_ssim: [0.62920851], total_l2: [0.04536878], total_loss: [0.22052070]
# Epoch: [58],step: [16270], mri_ssim: [0.15275395], pet_ssim: [0.52348602],  total_ssim: [0.67623997], total_l2: [0.04730500], total_loss: [0.23598549]
# Epoch: [58],step: [16275], mri_ssim: [0.16696131], pet_ssim: [0.50971460],  total_ssim: [0.67667592], total_l2: [0.05409583], total_loss: [0.24086986]
# Epoch: [58],step: [16280], mri_ssim: [0.14940363], pet_ssim: [0.48020351],  total_ssim: [0.62960714], total_l2: [0.04506580], total_loss: [0.22042821]
# Epoch: [58],step: [16285], mri_ssim: [0.12401748], pet_ssim: [0.46963549],  total_ssim: [0.59365296], total_l2: [0.04858195], total_loss: [0.21210325]
# Epoch: [58],step: [16290], mri_ssim: [0.09754366], pet_ssim: [0.45832992],  total_ssim: [0.55587357], total_l2: [0.04304393], total_loss: [0.19689284]
# Epoch: [58],step: [16295], mri_ssim: [0.06149662], pet_ssim: [0.51886994],  total_ssim: [0.58036655], total_l2: [0.04474518], total_loss: [0.20543160]
# Epoch: [58],step: [16300], mri_ssim: [0.12027669], pet_ssim: [0.52372277],  total_ssim: [0.64399946], total_l2: [0.04194546], total_loss: [0.22256166]
# Epoch: [58],step: [16305], mri_ssim: [0.12707925], pet_ssim: [0.48508334],  total_ssim: [0.61216259], total_l2: [0.04280629], total_loss: [0.21361318]
# Epoch: [58],step: [16310], mri_ssim: [0.14182341], pet_ssim: [0.48663938],  total_ssim: [0.62846279], total_l2: [0.04882425], total_loss: [0.22271582]
# Epoch: [58],step: [16315], mri_ssim: [0.17653370], pet_ssim: [0.47325218],  total_ssim: [0.64978588], total_l2: [0.04747468], total_loss: [0.22816804]
# Epoch: [58],step: [16320], mri_ssim: [0.16694212], pet_ssim: [0.43563879],  total_ssim: [0.60258090], total_l2: [0.05203148], total_loss: [0.21719632]
# Epoch: [58],step: [16325], mri_ssim: [0.15290070], pet_ssim: [0.39691901],  total_ssim: [0.54981971], total_l2: [0.04317551], total_loss: [0.19516878]
# Epoch: [58],step: [16330], mri_ssim: [0.13470191], pet_ssim: [0.36867815],  total_ssim: [0.50338006], total_l2: [0.03945329], total_loss: [0.17863134]
# Epoch: [58],step: [16335], mri_ssim: [0.12314957], pet_ssim: [0.34352726],  total_ssim: [0.46667683], total_l2: [0.03947024], total_loss: [0.16763222]
# Epoch: [58],step: [16340], mri_ssim: [0.07421482], pet_ssim: [0.31327409],  total_ssim: [0.38748890], total_l2: [0.02994367], total_loss: [0.13720724]
# Epoch: [59],step: [16345], mri_ssim: [0.25580597], pet_ssim: [0.38053870],  total_ssim: [0.63634467], total_l2: [0.01716192], total_loss: [0.20291676]
# Epoch: [59],step: [16350], mri_ssim: [0.22575080], pet_ssim: [0.26985669],  total_ssim: [0.49560750], total_l2: [0.01225047], total_loss: [0.15725757]
# Epoch: [59],step: [16355], mri_ssim: [0.19254124], pet_ssim: [0.30430865],  total_ssim: [0.49684989], total_l2: [0.01789703], total_loss: [0.16158289]
# Epoch: [59],step: [16360], mri_ssim: [0.20135880], pet_ssim: [0.42180073],  total_ssim: [0.62315953], total_l2: [0.02656259], total_loss: [0.20554167]
# Epoch: [59],step: [16365], mri_ssim: [0.21946669], pet_ssim: [0.35610211],  total_ssim: [0.57556880], total_l2: [0.01728491], total_loss: [0.18477008]
# Epoch: [59],step: [16370], mri_ssim: [0.16821814], pet_ssim: [0.44645703],  total_ssim: [0.61467516], total_l2: [0.02361852], total_loss: [0.20093551]
# Epoch: [59],step: [16375], mri_ssim: [0.18633217], pet_ssim: [0.40743929],  total_ssim: [0.59377146], total_l2: [0.03694368], total_loss: [0.20399202]
# Epoch: [59],step: [16380], mri_ssim: [0.16867530], pet_ssim: [0.32993853],  total_ssim: [0.49861383], total_l2: [0.03367599], total_loss: [0.17315735]
# Epoch: [59],step: [16385], mri_ssim: [0.15730917], pet_ssim: [0.18635964],  total_ssim: [0.34366882], total_l2: [0.02862234], total_loss: [0.12313629]
# Epoch: [59],step: [16390], mri_ssim: [0.13761568], pet_ssim: [0.17332351],  total_ssim: [0.31093919], total_l2: [0.02014060], total_loss: [0.10738018]
# Epoch: [59],step: [16395], mri_ssim: [0.10518306], pet_ssim: [0.17720431],  total_ssim: [0.28238738], total_l2: [0.01685904], total_loss: [0.09651755]
# Epoch: [59],step: [16400], mri_ssim: [0.10785508], pet_ssim: [0.15594333],  total_ssim: [0.26379842], total_l2: [0.01474910], total_loss: [0.08946390]
# Epoch: [59],step: [16405], mri_ssim: [0.09432280], pet_ssim: [0.15423816],  total_ssim: [0.24856097], total_l2: [0.01561108], total_loss: [0.08549605]
# Epoch: [59],step: [16410], mri_ssim: [0.08954340], pet_ssim: [0.14117312],  total_ssim: [0.23071653], total_l2: [0.01612756], total_loss: [0.08050425]
# Epoch: [59],step: [16415], mri_ssim: [0.21396041], pet_ssim: [0.38019729],  total_ssim: [0.59415770], total_l2: [0.02484914], total_loss: [0.19564171]
# Epoch: [59],step: [16420], mri_ssim: [0.19637114], pet_ssim: [0.25486535],  total_ssim: [0.45123649], total_l2: [0.01919252], total_loss: [0.14880572]
# Epoch: [59],step: [16425], mri_ssim: [0.15482950], pet_ssim: [0.25264466],  total_ssim: [0.40747416], total_l2: [0.01303083], total_loss: [0.13136382]
# Epoch: [59],step: [16430], mri_ssim: [0.16109288], pet_ssim: [0.22205901],  total_ssim: [0.38315189], total_l2: [0.02089510], total_loss: [0.12957214]
# Epoch: [59],step: [16435], mri_ssim: [0.15612745], pet_ssim: [0.31322706],  total_ssim: [0.46935451], total_l2: [0.02207496], total_loss: [0.15625884]
# Epoch: [59],step: [16440], mri_ssim: [0.14257520], pet_ssim: [0.23887706],  total_ssim: [0.38145226], total_l2: [0.01324713], total_loss: [0.12370867]
# Epoch: [59],step: [16445], mri_ssim: [0.20845395], pet_ssim: [0.34476501],  total_ssim: [0.55321896], total_l2: [0.02236775], total_loss: [0.18162312]
# Epoch: [59],step: [16450], mri_ssim: [0.16331458], pet_ssim: [0.21348774],  total_ssim: [0.37680233], total_l2: [0.01744042], total_loss: [0.12524900]
# Epoch: [59],step: [16455], mri_ssim: [0.43924093], pet_ssim: [0.32819331],  total_ssim: [0.76743424], total_l2: [0.02331989], total_loss: [0.24655421]
# Epoch: [59],step: [16460], mri_ssim: [0.23976886], pet_ssim: [0.39847022],  total_ssim: [0.63823909], total_l2: [0.02740155], total_loss: [0.21065283]
# Epoch: [59],step: [16465], mri_ssim: [0.15195394], pet_ssim: [0.25839520],  total_ssim: [0.41034913], total_l2: [0.01085289], total_loss: [0.13070177]
# Epoch: [59],step: [16470], mri_ssim: [0.15301168], pet_ssim: [0.21219242],  total_ssim: [0.36520410], total_l2: [0.01942159], total_loss: [0.12315635]
# Epoch: [59],step: [16475], mri_ssim: [0.19022965], pet_ssim: [0.31581002],  total_ssim: [0.50603968], total_l2: [0.02735783], total_loss: [0.17096239]
# Epoch: [59],step: [16480], mri_ssim: [0.09143686], pet_ssim: [0.36421651],  total_ssim: [0.45565337], total_l2: [0.03082554], total_loss: [0.15827389]
# Epoch: [59],step: [16485], mri_ssim: [0.13941157], pet_ssim: [0.38941914],  total_ssim: [0.52883071], total_l2: [0.03748823], total_loss: [0.18489099]
# Epoch: [59],step: [16490], mri_ssim: [0.16791058], pet_ssim: [0.37561184],  total_ssim: [0.54352242], total_l2: [0.03725143], total_loss: [0.18913274]
# Epoch: [59],step: [16495], mri_ssim: [0.16103977], pet_ssim: [0.37807739],  total_ssim: [0.53911716], total_l2: [0.04441679], total_loss: [0.19282690]
# Epoch: [59],step: [16500], mri_ssim: [0.16472340], pet_ssim: [0.38168961],  total_ssim: [0.54641300], total_l2: [0.03948355], total_loss: [0.19156238]
# Epoch: [59],step: [16505], mri_ssim: [0.15020323], pet_ssim: [0.38874543],  total_ssim: [0.53894866], total_l2: [0.03572080], total_loss: [0.18668917]
# Epoch: [59],step: [16510], mri_ssim: [0.12425357], pet_ssim: [0.43964720],  total_ssim: [0.56390077], total_l2: [0.03731667], total_loss: [0.19529191]
# Epoch: [59],step: [16515], mri_ssim: [0.11842567], pet_ssim: [0.46305895],  total_ssim: [0.58148462], total_l2: [0.03856231], total_loss: [0.20143901]
# Epoch: [59],step: [16520], mri_ssim: [0.08882642], pet_ssim: [0.45839489],  total_ssim: [0.54722130], total_l2: [0.03885588], total_loss: [0.19136551]
# Epoch: [59],step: [16525], mri_ssim: [0.06545246], pet_ssim: [0.43156707],  total_ssim: [0.49701953], total_l2: [0.03785308], total_loss: [0.17560302]
# Epoch: [59],step: [16530], mri_ssim: [0.08301413], pet_ssim: [0.40600562],  total_ssim: [0.48901975], total_l2: [0.03729929], total_loss: [0.17281543]
# Epoch: [59],step: [16535], mri_ssim: [0.13797128], pet_ssim: [0.45576024],  total_ssim: [0.59373152], total_l2: [0.04639059], total_loss: [0.21059288]
# Epoch: [59],step: [16540], mri_ssim: [0.17706728], pet_ssim: [0.46044409],  total_ssim: [0.63751137], total_l2: [0.04295713], total_loss: [0.22132342]
# Epoch: [59],step: [16545], mri_ssim: [0.15957683], pet_ssim: [0.50346053],  total_ssim: [0.66303736], total_l2: [0.04568326], total_loss: [0.23088950]
# Epoch: [59],step: [16550], mri_ssim: [0.17056441], pet_ssim: [0.51741755],  total_ssim: [0.68798196], total_l2: [0.04272927], total_loss: [0.23630509]
# Epoch: [59],step: [16555], mri_ssim: [0.15614676], pet_ssim: [0.49543130],  total_ssim: [0.65157807], total_l2: [0.04847604], total_loss: [0.22940665]
# Epoch: [59],step: [16560], mri_ssim: [0.13671720], pet_ssim: [0.46410084],  total_ssim: [0.60081804], total_l2: [0.04886959], total_loss: [0.21445413]
# Epoch: [59],step: [16565], mri_ssim: [0.10774910], pet_ssim: [0.46046692],  total_ssim: [0.56821603], total_l2: [0.04646302], total_loss: [0.20298892]
# Epoch: [59],step: [16570], mri_ssim: [0.05679047], pet_ssim: [0.40007651],  total_ssim: [0.45686698], total_l2: [0.03617657], total_loss: [0.16238371]
# Epoch: [59],step: [16575], mri_ssim: [0.08006209], pet_ssim: [0.55243838],  total_ssim: [0.63250047], total_l2: [0.04403808], total_loss: [0.22057681]
# Epoch: [59],step: [16580], mri_ssim: [0.13683337], pet_ssim: [0.49423540],  total_ssim: [0.63106877], total_l2: [0.04219538], total_loss: [0.21885741]
# Epoch: [59],step: [16585], mri_ssim: [0.12520850], pet_ssim: [0.49970269],  total_ssim: [0.62491119], total_l2: [0.04576819], total_loss: [0.21951109]
# Epoch: [59],step: [16590], mri_ssim: [0.15836620], pet_ssim: [0.45474440],  total_ssim: [0.61311060], total_l2: [0.04720959], total_loss: [0.21697989]
# Epoch: [59],step: [16595], mri_ssim: [0.16005099], pet_ssim: [0.43143892],  total_ssim: [0.59148991], total_l2: [0.04589967], total_loss: [0.20957674]
# Epoch: [59],step: [16600], mri_ssim: [0.16388571], pet_ssim: [0.41547680],  total_ssim: [0.57936251], total_l2: [0.04459285], total_loss: [0.20502375]
# Epoch: [59],step: [16605], mri_ssim: [0.15510726], pet_ssim: [0.37469107],  total_ssim: [0.52979833], total_l2: [0.04232553], total_loss: [0.18856739]
# Epoch: [59],step: [16610], mri_ssim: [0.13364357], pet_ssim: [0.35176474],  total_ssim: [0.48540831], total_l2: [0.03831568], total_loss: [0.17244346]
# Epoch: [59],step: [16615], mri_ssim: [0.09224737], pet_ssim: [0.32852495],  total_ssim: [0.42077231], total_l2: [0.03318250], total_loss: [0.14945945]
# Epoch: [59],step: [16620], mri_ssim: [0.03926873], pet_ssim: [0.29629838],  total_ssim: [0.33556712], total_l2: [0.02463779], total_loss: [0.11791659]
# *************obtained net model
# finish fusing
